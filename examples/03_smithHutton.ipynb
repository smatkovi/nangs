# %% [markdown]
# ## Smith-Hutton Problem
#
# We want to solve the following PDE:
#
# \begin{equation}
#     u \frac{\partial \phi}{\partial x} + v \frac{\partial \phi}{\partial y} = 0
# \end{equation}
#
# The independen variables (i.e, $x$, $y$) are used as input values for the NN, and the solution (i.e. $\phi(x,y)$) is the output. In order to find the solution, at each step the NN outputs are derived w.r.t the inputs. Then, a loss function that matches the PDE is built and the weights are updated accordingly. If the loss function goes to zero, we can assume that our NN is indeed the solution to our PDE. We will try to find a general solution for different values of $u$, so it will be set also as an input. The geometry of the problem is as follows:
#
# ![sh](pics/sh.png)

# %%
# autoreload nangs
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
#imports
import math
import numpy as np 
import matplotlib.pyplot as plt 
import torch

# %% [markdown]
# First we define our PDE and set the values for training.

# %%
from nangs.pde import PDE
from nangs.bocos import PeriodicBoco, DirichletBoco, NeumannBoco
from nangs.solutions import MLP

class MyPDE(PDE):
    def __init__(self, inputs=None, outputs=None):
        super().__init__(inputs, outputs)
    def computePDELoss(self, grads, inputs, outputs, params): 
        dpdx, dpdy = grads['p']['x'], grads['p']['y']
        x, y = inputs['x'], inputs['y']
        u, v = 2*y*(1-x**2), -2*x*(1-y**2)
        return [u*dpdx + v*dpdy]

# instanciate pde
pde = MyPDE(inputs=['x', 'y'], outputs=['p'])

# define input values
x = np.linspace(-1,1,60)
y = np.linspace(0,1,30)

pde.setValues({'x': x[1:-1], 'y': y[1:-1]})

# %% [markdown]
# Boundary conditions.

# %%
# left and rigth b.c 
ALPHA = 10
x1 = np.array([-1, 1])
p = np.zeros(2*len(y))
for i in range(2*len(y)): p[i] = 1. - math.tanh(ALPHA)
boco = DirichletBoco('left_rigth', {'x': x1, 'y': y}, {'p': p})
pde.addBoco(boco)

# top b.c 
p = np.zeros(len(x))
for i in range(len(x)): p[i] = 1. - math.tanh(ALPHA)
boco = DirichletBoco('top', {'x': x, 'y': y[-1:]}, {'p': p})
pde.addBoco(boco)

# bottom b.c
x1, x2, p1 = [], [], []
for i in range(len(x)): 
    if x[i] < 0:
        x1.append(x[i])
        p1.append(1.+math.tanh(ALPHA*(2*x[i]+1)))
    else:
        x2.append(x[i])
x1, x2, p1 = np.array(x1), np.array(x2), np.array(p1) 

# bottom left b.c
boco = DirichletBoco('bottom_left', {'x': x1, 'y': y[:1]}, {'p': p1})
pde.addBoco(boco)

# bottom right b.c
boco = NeumannBoco('bottom_right', {'x': x2, 'y': y[:1]}, grads={'p': 'y'})
pde.addBoco(boco)

# %%
plt.plot(x1,p1)
plt.xlabel('x')
plt.ylabel('p      ', rotation=np.pi/2)
plt.title('Solution at y=0')
plt.grid()
plt.show()

# %% [markdown]
# The objective is to reproduce the inflow ($y$=0 and $x<0$) at the outlet ($y$=0 and $x>0$).

# %% [markdown]
# Now we define a topology for our solution and set the training parameters. Then we can find a solution for our PDE.

# %%
# define solution topology
mlp = MLP(pde.n_inputs, pde.n_outputs, 5, 2048)
optimizer = torch.optim.Adam(mlp.parameters(), lr=3e-4)
pde.compile(mlp, optimizer)

# %%
# find the solution
hist = pde.solve()
# Out:
# Epoch 1/30 Losses 0.35488
#  PDE  [ 0.03867 ]
#  left_rigth 0.01197
#  top 0.00970
#  bottom_left 0.27590
#  bottom_right 0.01865<p>Epoch 2/30 Losses 0.04847
#  PDE  [ 0.01998 ]
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.02552
#  bottom_right 0.00294<p>Epoch 3/30 Losses 0.02898
#  PDE  [ 0.01335 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.01449
#  bottom_right 0.00111<p>Epoch 4/30 Losses 0.02053
#  PDE  [ 0.01016 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00727
#  bottom_right 0.00308<p>Epoch 5/30 Losses 0.01547
#  PDE  [ 0.00805 ]
#  left_rigth 0.00002
#  top 0.00001
#  bottom_left 0.00539
#  bottom_right 0.00200<p>Epoch 6/30 Losses 0.01908
#  PDE  [ 0.00914 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00651
#  bottom_right 0.00339<p>Epoch 7/30 Losses 0.01439
#  PDE  [ 0.00614 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00542
#  bottom_right 0.00280<p>Epoch 8/30 Losses 0.00852
#  PDE  [ 0.00485 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00249
#  bottom_right 0.00117<p>Epoch 9/30 Losses 0.00758
#  PDE  [ 0.00421 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00219
#  bottom_right 0.00117<p>Epoch 10/30 Losses 0.02043
#  PDE  [ 0.00952 ]
#  left_rigth 0.00005
#  top 0.00005
#  bottom_left 0.00928
#  bottom_right 0.00154<p>Epoch 11/30 Losses 0.03349
#  PDE  [ 0.01048 ]
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.02116
#  bottom_right 0.00182<p>Epoch 12/30 Losses 0.00724
#  PDE  [ 0.00399 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00175
#  bottom_right 0.00150<p>Epoch 13/30 Losses 0.00572
#  PDE  [ 0.00308 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00121
#  bottom_right 0.00143<p>Epoch 14/30 Losses 0.00490
#  PDE  [ 0.00314 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00110
#  bottom_right 0.00065<p>Epoch 15/30 Losses 0.00719
#  PDE  [ 0.00439 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00205
#  bottom_right 0.00074<p>Epoch 16/30 Losses 0.00584
#  PDE  [ 0.00312 ]
#  left_rigth 0.00000
#  top 0.00001
#  bottom_left 0.00155
#  bottom_right 0.00115<p>Epoch 17/30 Losses 0.00584
#  PDE  [ 0.00343 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00130
#  bottom_right 0.00110<p>Epoch 18/30 Losses 0.00854
#  PDE  [ 0.00421 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00262
#  bottom_right 0.00169<p>Epoch 19/30 Losses 0.00347
#  PDE  [ 0.00220 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00085
#  bottom_right 0.00042<p>Epoch 20/30 Losses 0.00486
#  PDE  [ 0.00302 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00118
#  bottom_right 0.00066<p>Epoch 21/30 Losses 0.00503
#  PDE  [ 0.00299 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00123
#  bottom_right 0.00081<p>Epoch 22/30 Losses 0.00625
#  PDE  [ 0.00415 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00166
#  bottom_right 0.00044<p>Epoch 23/30 Losses 0.00420
#  PDE  [ 0.00241 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00096
#  bottom_right 0.00083<p>Epoch 24/30 Losses 0.00993
#  PDE  [ 0.00554 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00324
#  bottom_right 0.00114<p>Epoch 25/30 Losses 0.00462
#  PDE  [ 0.00239 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00115
#  bottom_right 0.00108<p>Epoch 26/30 Losses 0.00392
#  PDE  [ 0.00243 ]
#  left_rigth 0.00001
#  top 0.00000
#  bottom_left 0.00091
#  bottom_right 0.00057<p>Epoch 27/30 Losses 0.00488
#  PDE  [ 0.00269 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00126
#  bottom_right 0.00093<p>Epoch 28/30 Losses 0.00635
#  PDE  [ 0.00322 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00205
#  bottom_right 0.00106<p>Epoch 29/30 Losses 0.00571
#  PDE  [ 0.00355 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00153
#  bottom_right 0.00063<p>Epoch 30/30 Losses 0.00748
#  PDE  [ 0.00333 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00207
#  bottom_right 0.00207
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.plot(hist['train_loss'], label="train_loss")
ax1.grid(True)
ax1.legend()
ax1.set_yscale("log")
for boco in pde.bocos:
    ax2.plot(hist['bocos'][boco.name], label=boco.name)
ax2.legend()
ax2.grid(True)
ax2.set_yscale("log")
plt.show()

# %% [markdown]
# Finally, we can evaluate our solution.

# %%
# evaluate the solution
x = np.linspace(-1,1,100)
y = np.linspace(0,1,50)
pde.evaluate({'x': x, 'y': y})
p = pde.outputs['p']
plt.imshow(p.reshape((len(y),len(x))), vmin=p.min(), vmax=p.max(), origin='lower',
           extent=[x.min(), x.max(), y.min(), y.max()])
plt.colorbar()
plt.show()

# %%
x = np.linspace(-1,1,200)
y = np.array([0])
pde.evaluate({'x': x, 'y': y})
p = pde.outputs['p']
plt.plot(x1,p1)
plt.plot(x1+1,np.flip(p1), label="exact")
plt.plot(x, p, '.k', label="predicted")
plt.legend()
plt.xlabel('x')
plt.ylabel('p      ', rotation=np.pi/2)
plt.title('Solution at y=0')
plt.grid()
plt.show()
