# %% [markdown]
# ## Smith-Hutton Problem
#
# We want to solve the following PDE:
#
# \begin{equation}
#     u \frac{\partial \phi}{\partial x} + v \frac{\partial \phi}{\partial y} = 0
# \end{equation}
#
# The independen variables (i.e, $x$, $y$) are used as input values for the NN, and the solution (i.e. $\phi(x,y)$) is the output. In order to find the solution, at each step the NN outputs are derived w.r.t the inputs. Then, a loss function that matches the PDE is built and the weights are updated accordingly. If the loss function goes to zero, we can assume that our NN is indeed the solution to our PDE. We will try to find a general solution for different values of $u$, so it will be set also as an input. The geometry of the problem is as follows:
#
# ![sh](pics/sh.png)

# %%
# autoreload nangs
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
#imports
import math
import numpy as np 
import matplotlib.pyplot as plt 

import torch
cuda = True
device = "cuda:0" if torch.cuda.is_available() and cuda else "cpu"

# %% [markdown]
# First we define our PDE and set the values for training.

# %%
from nangs.pde import PDE
from nangs.bocos import PeriodicBoco, DirichletBoco, NeumannBoco

class MyPDE(PDE):
    def __init__(self, inputs=None, outputs=None):
        super().__init__(inputs, outputs)
    def computePDELoss(self, grads, inputs, params): 
        dpdx, dpdy = grads['p']['x'], grads['p']['y']
        x, y = inputs['x'], inputs['y']
        u, v = 2*y*(1-x**2), -2*x*(1-y**2)
        return u*dpdx + v*dpdy

# instanciate pde
pde = MyPDE(inputs=['x', 'y'], outputs=['p'])

# define input values
x = np.linspace(-1,1,60)
y = np.linspace(0,1,30)

pde.setValues({'x': x, 'y': y})

x = np.linspace(-1,1,30)
y = np.linspace(0,1,15)
pde.setValues({'x': x, 'y': y}, train=False)

# %% [markdown]
# Boundary conditions.

# %%
# left and rigth b.c 
ALPHA = 10
x1, x2 = np.array([-1, 1]), np.array([1])
p = np.zeros(2*len(y))
for i in range(2*len(y)): p[i] = 1. - math.tanh(ALPHA)
boco = DirichletBoco('left_rigth', {'x': x1, 'y': y}, {'p': p})
pde.addBoco(boco)

# top b.c 
y2 = np.array([1])
p = np.zeros(len(x))
for i in range(len(x)): p[i] = 1. - math.tanh(ALPHA)
boco = DirichletBoco('top', {'x': x, 'y': y2}, {'p': p})
pde.addBoco(boco)

# bottom b.c
y1 = np.array([0])
x1, x2, p1 = [], [], []
for i in range(len(x)): 
    if x[i] < 0:
        x1.append(x[i])
        p1.append(1.+math.tanh(ALPHA*(2*x[i]+1)))
    else:
        x2.append(x[i])
x1, x2, p1 = np.array(x1), np.array(x2), np.array(p1) 

# bottom left b.c
boco = DirichletBoco('bottom_left', {'x': x1, 'y': y1}, {'p': p1})
pde.addBoco(boco)

# bottom right b.c
boco = NeumannBoco('bottom_right', {'x': x2, 'y': y1}, grads={'p': 'y'})
pde.addBoco(boco)

# %%
plt.plot(x1,p1)
plt.xlabel('x')
plt.ylabel('p      ', rotation=np.pi/2)
plt.title('Solution at y=0')
plt.grid()
plt.show()

# %% [markdown]
# The objective is to reproduce the inflow ($y$=0 and $x<0$) at the outlet ($y$=0 and $x>0$).

# %% [markdown]
# Now we define a topology for our solution and set the training parameters. Then we can find a solution for our PDE.

# %%
# define solution topology
topo = {'layers': 5, 'neurons': 1024, 'activations': 'relu'}
pde.buildSolution(topo)

# set optimization parameters
pde.compile(lr=0.0001, epochs=50, batch_size=64)

# %%
# find the solution
hist = pde.solve(device, 'sh_best.pth')
# Out:
# Epoch 1/50 Losses 1.04742
#  PDE  0.05186
#  left_rigth 0.02970
#  top 0.01785
#  bottom_left 0.93603
#  bottom_right 0.01197
#  Val 0.04113 <p>Epoch 2/50 Losses 0.10620
#  PDE  0.03760
#  left_rigth 0.00117
#  top 0.00130
#  bottom_left 0.05841
#  bottom_right 0.00772
#  Val 0.02245 <p>Epoch 3/50 Losses 0.05216
#  PDE  0.02336
#  left_rigth 0.00007
#  top 0.00003
#  bottom_left 0.02684
#  bottom_right 0.00186
#  Val 0.01815 <p>Epoch 4/50 Losses 0.04020
#  PDE  0.01874
#  left_rigth 0.00001
#  top 0.00000
#  bottom_left 0.02049
#  bottom_right 0.00096
#  Val 0.01350 <p>Epoch 5/50 Losses 0.03206
#  PDE  0.01362
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.01731
#  bottom_right 0.00113
#  Val 0.01027 <p>Epoch 6/50 Losses 0.02542
#  PDE  0.01131
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.01294
#  bottom_right 0.00117
#  Val 0.00909 <p>Epoch 7/50 Losses 0.02179
#  PDE  0.01096
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00994
#  bottom_right 0.00088
#  Val 0.01094 <p>Epoch 8/50 Losses 0.01817
#  PDE  0.00876
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00838
#  bottom_right 0.00099
#  Val 0.00718 <p>Epoch 9/50 Losses 0.01448
#  PDE  0.00741
#  left_rigth 0.00002
#  top 0.00003
#  bottom_left 0.00594
#  bottom_right 0.00108
#  Val 0.00544 <p>Epoch 10/50 Losses 0.01625
#  PDE  0.00807
#  left_rigth 0.00004
#  top 0.00004
#  bottom_left 0.00545
#  bottom_right 0.00265
#  Val 0.00836 <p>Epoch 11/50 Losses 0.01671
#  PDE  0.00795
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00611
#  bottom_right 0.00263
#  Val 0.00611 <p>Epoch 12/50 Losses 0.01291
#  PDE  0.00740
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00445
#  bottom_right 0.00104
#  Val 0.01062 <p>Epoch 13/50 Losses 0.01057
#  PDE  0.00603
#  left_rigth 0.00004
#  top 0.00004
#  bottom_left 0.00370
#  bottom_right 0.00076
#  Val 0.00533 <p>Epoch 14/50 Losses 0.01033
#  PDE  0.00651
#  left_rigth 0.00007
#  top 0.00007
#  bottom_left 0.00279
#  bottom_right 0.00089
#  Val 0.00922 <p>Epoch 15/50 Losses 0.01215
#  PDE  0.00644
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00366
#  bottom_right 0.00204
#  Val 0.00481 <p>Epoch 16/50 Losses 0.00778
#  PDE  0.00462
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00246
#  bottom_right 0.00065
#  Val 0.00619 <p>Epoch 17/50 Losses 0.00917
#  PDE  0.00527
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00206
#  bottom_right 0.00179
#  Val 0.00410 <p>Epoch 18/50 Losses 0.00653
#  PDE  0.00400
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00160
#  bottom_right 0.00089
#  Val 0.00456 <p>Epoch 19/50 Losses 0.00665
#  PDE  0.00478
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00096
#  bottom_right 0.00089
#  Val 0.00815 <p>Epoch 20/50 Losses 0.01062
#  PDE  0.00605
#  left_rigth 0.00008
#  top 0.00008
#  bottom_left 0.00263
#  bottom_right 0.00178
#  Val 0.00765 <p>Epoch 21/50 Losses 0.00930
#  PDE  0.00592
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00253
#  bottom_right 0.00082
#  Val 0.00414 <p>Epoch 22/50 Losses 0.00702
#  PDE  0.00482
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00133
#  bottom_right 0.00083
#  Val 0.00442 <p>Epoch 23/50 Losses 0.00701
#  PDE  0.00475
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00144
#  bottom_right 0.00080
#  Val 0.00600 <p>Epoch 24/50 Losses 0.01188
#  PDE  0.00810
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00250
#  bottom_right 0.00123
#  Val 0.00434 <p>Epoch 25/50 Losses 0.00967
#  PDE  0.00556
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00238
#  bottom_right 0.00171
#  Val 0.00317 <p>Epoch 26/50 Losses 0.00745
#  PDE  0.00480
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00203
#  bottom_right 0.00058
#  Val 0.00538 <p>Epoch 27/50 Losses 0.00736
#  PDE  0.00575
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00121
#  bottom_right 0.00035
#  Val 0.01264 <p>Epoch 28/50 Losses 0.00830
#  PDE  0.00582
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00196
#  bottom_right 0.00046
#  Val 0.00320 <p>Epoch 29/50 Losses 0.00631
#  PDE  0.00465
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00125
#  bottom_right 0.00036
#  Val 0.00544 <p>Epoch 30/50 Losses 0.00920
#  PDE  0.00566
#  left_rigth 0.00012
#  top 0.00012
#  bottom_left 0.00247
#  bottom_right 0.00082
#  Val 0.00509 <p>Epoch 31/50 Losses 0.00638
#  PDE  0.00460
#  left_rigth 0.00004
#  top 0.00004
#  bottom_left 0.00120
#  bottom_right 0.00049
#  Val 0.00381 <p>Epoch 32/50 Losses 0.00693
#  PDE  0.00466
#  left_rigth 0.00007
#  top 0.00007
#  bottom_left 0.00133
#  bottom_right 0.00080
#  Val 0.00399 <p>Epoch 33/50 Losses 0.00718
#  PDE  0.00453
#  left_rigth 0.00004
#  top 0.00004
#  bottom_left 0.00142
#  bottom_right 0.00115
#  Val 0.00256 <p>Epoch 34/50 Losses 0.00920
#  PDE  0.00656
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00138
#  bottom_right 0.00119
#  Val 0.01156 <p>Epoch 35/50 Losses 0.01251
#  PDE  0.00771
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00361
#  bottom_right 0.00114
#  Val 0.00286 <p>Epoch 36/50 Losses 0.00760
#  PDE  0.00520
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00152
#  bottom_right 0.00087
#  Val 0.00486 <p>Epoch 37/50 Losses 0.00842
#  PDE  0.00511
#  left_rigth 0.00005
#  top 0.00005
#  bottom_left 0.00200
#  bottom_right 0.00120
#  Val 0.00492 <p>Epoch 38/50 Losses 0.00890
#  PDE  0.00496
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00198
#  bottom_right 0.00192
#  Val 0.00317 <p>Epoch 39/50 Losses 0.00618
#  PDE  0.00400
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00119
#  bottom_right 0.00097
#  Val 0.00400 <p>Epoch 40/50 Losses 0.00784
#  PDE  0.00465
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00134
#  bottom_right 0.00180
#  Val 0.00367 <p>Epoch 41/50 Losses 0.00677
#  PDE  0.00439
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00175
#  bottom_right 0.00057
#  Val 0.00309 <p>Epoch 42/50 Losses 0.00483
#  PDE  0.00369
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00061
#  bottom_right 0.00048
#  Val 0.00442 <p>Epoch 43/50 Losses 0.00521
#  PDE  0.00385
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00081
#  bottom_right 0.00051
#  Val 0.00410 <p>Epoch 44/50 Losses 0.00610
#  PDE  0.00409
#  left_rigth 0.00005
#  top 0.00005
#  bottom_left 0.00086
#  bottom_right 0.00105
#  Val 0.00579 <p>Epoch 45/50 Losses 0.00585
#  PDE  0.00364
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00095
#  bottom_right 0.00122
#  Val 0.00551 <p>Epoch 46/50 Losses 0.00875
#  PDE  0.00529
#  left_rigth 0.00002
#  top 0.00003
#  bottom_left 0.00182
#  bottom_right 0.00158
#  Val 0.00515 <p>Epoch 47/50 Losses 0.00678
#  PDE  0.00455
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00145
#  bottom_right 0.00071
#  Val 0.00291 <p>Epoch 48/50 Losses 0.00546
#  PDE  0.00383
#  left_rigth 0.00006
#  top 0.00006
#  bottom_left 0.00091
#  bottom_right 0.00060
#  Val 0.00463 <p>Epoch 49/50 Losses 0.00691
#  PDE  0.00422
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00111
#  bottom_right 0.00153
#  Val 0.00531 <p>Epoch 50/50 Losses 0.00767
#  PDE  0.00431
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00135
#  bottom_right 0.00200
#  Val 0.00348

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.plot(hist['train_loss'], label="train_loss")
ax1.plot(hist['val_loss'], label="val_loss")
ax1.grid(True)
ax1.legend()
ax1.set_yscale("log")
for boco in pde.bocos:
    ax2.plot(hist['bocos'][boco.name], label=boco.name)
ax2.legend()
ax2.grid(True)
ax2.set_yscale("log")
plt.show()

# %% [markdown]
# Finally, we can evaluate our solution.

# %%
# evaluate the solution
pde.load_state_dict('sh_best.pth')
x = np.linspace(-1,1,30)
y = np.linspace(0,1,15)
p = pde.eval({'x': x, 'y': y}, device)
plt.imshow(p.reshape((len(y),len(x))), vmin=p.min(), vmax=p.max(), origin='lower',
           extent=[x.min(), x.max(), y.min(), y.max()])
plt.colorbar()
plt.show()

# %%
x = np.linspace(-1,1,50)
y = np.array([0])
p = pde.eval({'x': x, 'y': y}, device)
plt.plot(x1,p1)
plt.plot(x1+1,np.flip(p1), label="exact")
plt.plot(x,p, '.k', label="predicted")
plt.legend()
plt.xlabel('x')
plt.ylabel('p      ', rotation=np.pi/2)
plt.title('Solution at y=0')
plt.grid()
plt.show()
