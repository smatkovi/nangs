# %% [markdown]
# ## Smith-Hutton Problem
#
# We want to solve the following PDE:
#
# \begin{equation}
#     u \frac{\partial \phi}{\partial x} + v \frac{\partial \phi}{\partial y} = 0
# \end{equation}
#
# The independen variables (i.e, $x$, $y$) are used as input values for the NN, and the solution (i.e. $\phi(x,y)$) is the output. In order to find the solution, at each step the NN outputs are derived w.r.t the inputs. Then, a loss function that matches the PDE is built and the weights are updated accordingly. If the loss function goes to zero, we can assume that our NN is indeed the solution to our PDE. We will try to find a general solution for different values of $u$, so it will be set also as an input. The geometry of the problem is as follows:
#
# ![sh](pics/sh.png)

# %%
# autoreload nangs
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
#imports
import math
import numpy as np 
import matplotlib.pyplot as plt 

import torch
cuda = True
device = "cuda:0" if torch.cuda.is_available() and cuda else "cpu"

# %% [markdown]
# First we define our PDE and set the values for training.

# %%
from nangs.pde import PDE
from nangs.bocos import PeriodicBoco, DirichletBoco, NeumannBoco

class MyPDE(PDE):
    def __init__(self, inputs=None, outputs=None):
        super().__init__(inputs, outputs)
    def computePDELoss(self, grads, inputs, params): 
        dpdx, dpdy = grads['p']['x'], grads['p']['y']
        x, y = inputs['x'], inputs['y']
        u, v = 2*y*(1-x**2), -2*x*(1-y**2)
        return u*dpdx + v*dpdy

# instanciate pde
pde = MyPDE(inputs=['x', 'y'], outputs=['p'])

# define input values
x = np.linspace(-1,1,60)
y = np.linspace(0,1,30)

pde.setValues({'x': x, 'y': y})

x = np.linspace(-1,1,30)
y = np.linspace(0,1,15)
pde.setValues({'x': x, 'y': y}, train=False)

# %% [markdown]
# Boundary conditions.

# %%
# left and rigth b.c 
ALPHA = 10
x1, x2 = np.array([-1, 1]), np.array([1])
p = np.zeros(2*len(y))
for i in range(2*len(y)): p[i] = 1. - math.tanh(ALPHA)
boco = DirichletBoco('left_rigth', {'x': x1, 'y': y}, {'p': p})
pde.addBoco(boco)

# top b.c 
y2 = np.array([1])
p = np.zeros(len(x))
for i in range(len(x)): p[i] = 1. - math.tanh(ALPHA)
boco = DirichletBoco('top', {'x': x, 'y': y2}, {'p': p})
pde.addBoco(boco)

# bottom b.c
y1 = np.array([0])
x1, x2, p1 = [], [], []
for i in range(len(x)): 
    if x[i] < 0:
        x1.append(x[i])
        p1.append(1.+math.tanh(ALPHA*(2*x[i]+1)))
    else:
        x2.append(x[i])
x1, x2, p1 = np.array(x1), np.array(x2), np.array(p1) 

# bottom left b.c
boco = DirichletBoco('bottom_left', {'x': x1, 'y': y1}, {'p': p1})
pde.addBoco(boco)

# bottom right b.c
boco = NeumannBoco('bottom_right', {'x': x2, 'y': y1}, grads={'p': 'y'})
pde.addBoco(boco)

# %%
plt.plot(x1,p1)
plt.xlabel('x')
plt.ylabel('p      ', rotation=np.pi/2)
plt.title('Solution at y=0')
plt.grid()
plt.show()

# %% [markdown]
# The objective is to reproduce the inflow ($y$=0 and $x<0$) at the outlet ($y$=0 and $x>0$).

# %% [markdown]
# Now we define a topology for our solution and set the training parameters. Then we can find a solution for our PDE.

# %%
# define solution topology
topo = {'layers': 5, 'neurons': 1024, 'activations': 'relu'}
pde.buildSolution(topo)

# set optimization parameters
pde.compile(lr=0.0001, epochs=50, batch_size=64)

# %%
# find the solution
hist = pde.solve(device, 'sh_best.pth')
# Out:
# Epoch 1/50 Losses 1.11402
#  PDE  0.04780
#  left_rigth 0.03255
#  top 0.01464
#  bottom_left 1.00725
#  bottom_right 0.01177
#  Val 0.16465 <p>Epoch 2/50 Losses 0.15175
#  PDE  0.05646
#  left_rigth 0.00162
#  top 0.00182
#  bottom_left 0.08088
#  bottom_right 0.01096
#  Val 0.02490 <p>Epoch 3/50 Losses 0.05764
#  PDE  0.02557
#  left_rigth 0.00008
#  top 0.00004
#  bottom_left 0.02994
#  bottom_right 0.00201
#  Val 0.02404 <p>Epoch 4/50 Losses 0.04503
#  PDE  0.02515
#  left_rigth 0.00002
#  top 0.00001
#  bottom_left 0.01901
#  bottom_right 0.00084
#  Val 0.01658 <p>Epoch 5/50 Losses 0.03871
#  PDE  0.01927
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.01876
#  bottom_right 0.00068
#  Val 0.01492 <p>Epoch 6/50 Losses 0.02994
#  PDE  0.01431
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.01479
#  bottom_right 0.00084
#  Val 0.01441 <p>Epoch 7/50 Losses 0.02768
#  PDE  0.01446
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.01188
#  bottom_right 0.00133
#  Val 0.01074 <p>Epoch 8/50 Losses 0.02705
#  PDE  0.01316
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.01304
#  bottom_right 0.00084
#  Val 0.01104 <p>Epoch 9/50 Losses 0.02237
#  PDE  0.01115
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00927
#  bottom_right 0.00192
#  Val 0.01048 <p>Epoch 10/50 Losses 0.02199
#  PDE  0.01211
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00877
#  bottom_right 0.00108
#  Val 0.01462 <p>Epoch 11/50 Losses 0.02974
#  PDE  0.01632
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.01085
#  bottom_right 0.00254
#  Val 0.00965 <p>Epoch 12/50 Losses 0.02195
#  PDE  0.01048
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00933
#  bottom_right 0.00213
#  Val 0.01393 <p>Epoch 13/50 Losses 0.02012
#  PDE  0.01093
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00670
#  bottom_right 0.00248
#  Val 0.01029 <p>Epoch 14/50 Losses 0.01990
#  PDE  0.00937
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00643
#  bottom_right 0.00409
#  Val 0.00631 <p>Epoch 15/50 Losses 0.01271
#  PDE  0.00670
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00508
#  bottom_right 0.00093
#  Val 0.00936 <p>Epoch 16/50 Losses 0.01327
#  PDE  0.00786
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00448
#  bottom_right 0.00092
#  Val 0.00438 <p>Epoch 17/50 Losses 0.01135
#  PDE  0.00658
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00381
#  bottom_right 0.00096
#  Val 0.00489 <p>Epoch 18/50 Losses 0.01430
#  PDE  0.00780
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00470
#  bottom_right 0.00176
#  Val 0.00540 <p>Epoch 19/50 Losses 0.00950
#  PDE  0.00552
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00342
#  bottom_right 0.00055
#  Val 0.00440 <p>Epoch 20/50 Losses 0.00825
#  PDE  0.00523
#  left_rigth 0.00005
#  top 0.00005
#  bottom_left 0.00232
#  bottom_right 0.00060
#  Val 0.00989 <p>Epoch 21/50 Losses 0.00885
#  PDE  0.00612
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00208
#  bottom_right 0.00061
#  Val 0.00597 <p>Epoch 22/50 Losses 0.01422
#  PDE  0.00919
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00367
#  bottom_right 0.00134
#  Val 0.00444 <p>Epoch 23/50 Losses 0.00883
#  PDE  0.00486
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00325
#  bottom_right 0.00067
#  Val 0.00434 <p>Epoch 24/50 Losses 0.00851
#  PDE  0.00589
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00184
#  bottom_right 0.00075
#  Val 0.00556 <p>Epoch 25/50 Losses 0.01045
#  PDE  0.00714
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00260
#  bottom_right 0.00069
#  Val 0.00373 <p>Epoch 26/50 Losses 0.01041
#  PDE  0.00542
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00277
#  bottom_right 0.00220
#  Val 0.00378 <p>Epoch 27/50 Losses 0.00861
#  PDE  0.00535
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00205
#  bottom_right 0.00120
#  Val 0.00427 <p>Epoch 28/50 Losses 0.01040
#  PDE  0.00613
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00230
#  bottom_right 0.00191
#  Val 0.00493 <p>Epoch 29/50 Losses 0.01132
#  PDE  0.00666
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00311
#  bottom_right 0.00151
#  Val 0.00595 <p>Epoch 30/50 Losses 0.00930
#  PDE  0.00528
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00279
#  bottom_right 0.00121
#  Val 0.00455 <p>Epoch 31/50 Losses 0.00748
#  PDE  0.00531
#  left_rigth 0.00004
#  top 0.00004
#  bottom_left 0.00162
#  bottom_right 0.00047
#  Val 0.00374 <p>Epoch 32/50 Losses 0.00643
#  PDE  0.00454
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00125
#  bottom_right 0.00060
#  Val 0.00376 <p>Epoch 33/50 Losses 0.00670
#  PDE  0.00513
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00100
#  bottom_right 0.00055
#  Val 0.00758 <p>Epoch 34/50 Losses 0.00961
#  PDE  0.00574
#  left_rigth 0.00005
#  top 0.00005
#  bottom_left 0.00195
#  bottom_right 0.00183
#  Val 0.00503 <p>Epoch 35/50 Losses 0.00809
#  PDE  0.00454
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00221
#  bottom_right 0.00132
#  Val 0.00747 <p>Epoch 36/50 Losses 0.00624
#  PDE  0.00481
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00109
#  bottom_right 0.00031
#  Val 0.00483 <p>Epoch 37/50 Losses 0.00604
#  PDE  0.00473
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00080
#  bottom_right 0.00047
#  Val 0.00644 <p>Epoch 38/50 Losses 0.00810
#  PDE  0.00604
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00158
#  bottom_right 0.00043
#  Val 0.00414 <p>Epoch 39/50 Losses 0.00724
#  PDE  0.00479
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00156
#  bottom_right 0.00087
#  Val 0.00440 <p>Epoch 40/50 Losses 0.00490
#  PDE  0.00373
#  left_rigth 0.00004
#  top 0.00004
#  bottom_left 0.00093
#  bottom_right 0.00016
#  Val 0.00376 <p>Epoch 41/50 Losses 0.00628
#  PDE  0.00445
#  left_rigth 0.00003
#  top 0.00004
#  bottom_left 0.00069
#  bottom_right 0.00106
#  Val 0.00585 <p>Epoch 42/50 Losses 0.00789
#  PDE  0.00561
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00183
#  bottom_right 0.00041
#  Val 0.00814 <p>Epoch 43/50 Losses 0.00633
#  PDE  0.00373
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00124
#  bottom_right 0.00129
#  Val 0.00341 <p>Epoch 44/50 Losses 0.00725
#  PDE  0.00399
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00131
#  bottom_right 0.00189
#  Val 0.00341 <p>Epoch 45/50 Losses 0.00504
#  PDE  0.00356
#  left_rigth 0.00004
#  top 0.00004
#  bottom_left 0.00096
#  bottom_right 0.00044
#  Val 0.00479 <p>Epoch 46/50 Losses 0.00569
#  PDE  0.00409
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00072
#  bottom_right 0.00086
#  Val 0.00484 <p>Epoch 47/50 Losses 0.00808
#  PDE  0.00497
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00173
#  bottom_right 0.00136
#  Val 0.00362 <p>Epoch 48/50 Losses 0.00653
#  PDE  0.00404
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00108
#  bottom_right 0.00140
#  Val 0.00420 <p>Epoch 49/50 Losses 0.00596
#  PDE  0.00393
#  left_rigth 0.00002
#  top 0.00002
#  bottom_left 0.00135
#  bottom_right 0.00064
#  Val 0.00384 <p>Epoch 50/50 Losses 0.00500
#  PDE  0.00378
#  left_rigth 0.00005
#  top 0.00005
#  bottom_left 0.00073
#  bottom_right 0.00038
#  Val 0.00386

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.plot(hist['train_loss'], label="train_loss")
ax1.plot(hist['val_loss'], label="val_loss")
ax1.grid(True)
ax1.legend()
ax1.set_yscale("log")
for boco in pde.bocos:
    ax2.plot(hist['bocos'][boco.name], label=boco.name)
ax2.legend()
ax2.grid(True)
ax2.set_yscale("log")
plt.show()

# %% [markdown]
# Finally, we can evaluate our solution.

# %%
# evaluate the solution
pde.load_state_dict('sh_best.pth')
x = np.linspace(-1,1,100)
y = np.linspace(0,1,50)
p = pde.evaluate({'x': x, 'y': y}, device)
plt.imshow(p.reshape((len(y),len(x))), vmin=p.min(), vmax=p.max(), origin='lower',
           extent=[x.min(), x.max(), y.min(), y.max()])
plt.colorbar()
plt.show()

# %%
x = np.linspace(-1,1,200)
y = np.array([0])
p = pde.evaluate({'x': x, 'y': y}, device)
plt.plot(x1,p1)
plt.plot(x1+1,np.flip(p1), label="exact")
plt.plot(x,p, '.k', label="predicted")
plt.legend()
plt.xlabel('x')
plt.ylabel('p      ', rotation=np.pi/2)
plt.title('Solution at y=0')
plt.grid()
plt.show()
