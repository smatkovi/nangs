# %% [markdown]
# # One-dimensional advection equation
#
# We want to solve the following PDE:
#
# \begin{equation}
#     \frac{\partial \phi}{\partial t} + u \frac{\partial \phi}{\partial x} = 0
# \end{equation}
#
# The independen variables (i.e, $x$ and $t$) are used as input values for the NN, and the solution (i.e. $\phi$) is the output. In order to find the solution, at each step the NN outputs are derived w.r.t the inputs. Then, a loss function that matches the PDE is built and the weights are updated accordingly. If the loss function goes to zero, we can assume that our NN is indeed the solution to our PDE. We will try to find a general solution for different values of $u$, so it will be set also as an input.

# %%
# autoreload nangs
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# imports
import math
import numpy as np 
import matplotlib.pyplot as plt 

import torch
cuda = True
device = "cuda" if torch.cuda.is_available() and cuda else "cpu"

# %% [markdown]
# ## Define PDE
#
# First we define our PDE and set the values for training.

# %%
# imports
from nangs.pde import PDE
from nangs.bocos import PeriodicBoco, DirichletBoco
from nangs.solutions import MLP

# define our PDE
class MyPDE(PDE):
    def __init__(self, inputs=None, outputs=None):
        super().__init__(inputs, outputs)
    # the loss of our NN is the PDE !
    def computePDELoss(self, grads, inputs, outputs, params): 
        dpdt, dpdx = grads['p']['t'], grads['p']['x']
        u = inputs['u']
        return [dpdt + u*dpdx]

# instanciate pde with keys for inputs/outputs
pde = MyPDE(inputs=['x', 't', 'u'], outputs=['p'])

# define input values for training
x_t = np.linspace(0,1,20)
t_t = np.linspace(0,1,30)
u_t = np.linspace(0,1,10)
pde.setValues({'x': x_t, 't': t_t, 'u': u_t})

# periodic b.c for the space dimension
x1, x2 = np.array([0]), np.array([1])
boco = PeriodicBoco('boco', {'x': x1, 't': t_t, 'u': u_t}, {'x': x2, 't': t_t, 'u': u_t})
pde.addBoco(boco)

# initial condition (dirichlet for temporal dimension)
p00, p0 = np.sin(2.*math.pi*x_t), np.array([])
for i in u_t:
    p0 = np.concatenate((p0,p00)) # one for each value of 'u', keeping the order (x, t, u)
boco = DirichletBoco('initial_condition', {'x': x_t, 't': np.array([0]), 'u': u_t}, {'p': p0})
pde.addBoco(boco)

# define input values for validation
x_v = np.linspace(0,1,25)
t_v = np.linspace(0,1,15)
u_v = np.linspace(0,1,5)
pde.setValues({'x': x_v, 't': t_v, 'u': u_v}, train=False)

# %% [markdown]
# Now we define a topology for our solution and set the training parameters. Then we can find a solution for our PDE.

# %%
# define solution topology
mlp = MLP(pde.n_inputs, pde.n_outputs, 5, 2048)
optimizer = torch.optim.Adam(mlp.parameters(), lr=3e-4)
pde.compile(mlp, optimizer)

# %%
# find the solution
hist = pde.solve(epochs=50)
# Out:
# Epoch 1/50 Losses 0.14677
#  PDE  [ 0.02574 ]
#  boco 0.03002
#  initial_condition 0.09101
#  Val [ 0.01354 ]<p>Epoch 2/50 Losses 0.03251
#  PDE  [ 0.01017 ]
#  boco 0.01389
#  initial_condition 0.00845
#  Val [ 0.00935 ]<p>Epoch 3/50 Losses 0.02337
#  PDE  [ 0.00911 ]
#  boco 0.00912
#  initial_condition 0.00515
#  Val [ 0.00737 ]<p>Epoch 4/50 Losses 0.02536
#  PDE  [ 0.00793 ]
#  boco 0.01126
#  initial_condition 0.00617
#  Val [ 0.00757 ]<p>Epoch 5/50 Losses 0.02150
#  PDE  [ 0.00731 ]
#  boco 0.00904
#  initial_condition 0.00515
#  Val [ 0.00606 ]<p>Epoch 6/50 Losses 0.01879
#  PDE  [ 0.00740 ]
#  boco 0.00713
#  initial_condition 0.00426
#  Val [ 0.00587 ]<p>Epoch 7/50 Losses 0.01858
#  PDE  [ 0.00604 ]
#  boco 0.00805
#  initial_condition 0.00448
#  Val [ 0.00741 ]<p>Epoch 8/50 Losses 0.01760
#  PDE  [ 0.00778 ]
#  boco 0.00618
#  initial_condition 0.00364
#  Val [ 0.00880 ]<p>Epoch 9/50 Losses 0.01542
#  PDE  [ 0.00643 ]
#  boco 0.00584
#  initial_condition 0.00316
#  Val [ 0.00706 ]<p>Epoch 10/50 Losses 0.01792
#  PDE  [ 0.00671 ]
#  boco 0.00742
#  initial_condition 0.00379
#  Val [ 0.00545 ]<p>Epoch 11/50 Losses 0.01077
#  PDE  [ 0.00558 ]
#  boco 0.00327
#  initial_condition 0.00192
#  Val [ 0.00523 ]<p>Epoch 12/50 Losses 0.01853
#  PDE  [ 0.00655 ]
#  boco 0.00773
#  initial_condition 0.00424
#  Val [ 0.00476 ]<p>Epoch 13/50 Losses 0.01078
#  PDE  [ 0.00596 ]
#  boco 0.00309
#  initial_condition 0.00173
#  Val [ 0.00569 ]<p>Epoch 14/50 Losses 0.01768
#  PDE  [ 0.00687 ]
#  boco 0.00690
#  initial_condition 0.00391
#  Val [ 0.00534 ]<p>Epoch 15/50 Losses 0.01260
#  PDE  [ 0.00611 ]
#  boco 0.00402
#  initial_condition 0.00246
#  Val [ 0.00645 ]<p>Epoch 16/50 Losses 0.01240
#  PDE  [ 0.00594 ]
#  boco 0.00407
#  initial_condition 0.00239
#  Val [ 0.00689 ]<p>Epoch 17/50 Losses 0.01046
#  PDE  [ 0.00574 ]
#  boco 0.00287
#  initial_condition 0.00185
#  Val [ 0.00506 ]<p>Epoch 18/50 Losses 0.01050
#  PDE  [ 0.00505 ]
#  boco 0.00357
#  initial_condition 0.00188
#  Val [ 0.00567 ]<p>Epoch 19/50 Losses 0.01008
#  PDE  [ 0.00512 ]
#  boco 0.00307
#  initial_condition 0.00190
#  Val [ 0.00508 ]<p>Epoch 20/50 Losses 0.00937
#  PDE  [ 0.00482 ]
#  boco 0.00304
#  initial_condition 0.00152
#  Val [ 0.00594 ]<p>Epoch 21/50 Losses 0.00783
#  PDE  [ 0.00489 ]
#  boco 0.00177
#  initial_condition 0.00117
#  Val [ 0.00509 ]<p>Epoch 22/50 Losses 0.01480
#  PDE  [ 0.00550 ]
#  boco 0.00599
#  initial_condition 0.00331
#  Val [ 0.00576 ]<p>Epoch 23/50 Losses 0.01035
#  PDE  [ 0.00521 ]
#  boco 0.00293
#  initial_condition 0.00222
#  Val [ 0.00493 ]<p>Epoch 24/50 Losses 0.01132
#  PDE  [ 0.00510 ]
#  boco 0.00392
#  initial_condition 0.00231
#  Val [ 0.00451 ]<p>Epoch 25/50 Losses 0.00877
#  PDE  [ 0.00517 ]
#  boco 0.00230
#  initial_condition 0.00130
#  Val [ 0.00449 ]<p>Epoch 26/50 Losses 0.01080
#  PDE  [ 0.00488 ]
#  boco 0.00362
#  initial_condition 0.00230
#  Val [ 0.00637 ]<p>Epoch 27/50 Losses 0.01354
#  PDE  [ 0.00525 ]
#  boco 0.00560
#  initial_condition 0.00269
#  Val [ 0.00434 ]<p>Epoch 28/50 Losses 0.00800
#  PDE  [ 0.00518 ]
#  boco 0.00165
#  initial_condition 0.00117
#  Val [ 0.00465 ]<p>Epoch 29/50 Losses 0.00836
#  PDE  [ 0.00501 ]
#  boco 0.00206
#  initial_condition 0.00129
#  Val [ 0.00446 ]<p>Epoch 30/50 Losses 0.01373
#  PDE  [ 0.00517 ]
#  boco 0.00527
#  initial_condition 0.00329
#  Val [ 0.00877 ]<p>Epoch 31/50 Losses 0.00681
#  PDE  [ 0.00490 ]
#  boco 0.00106
#  initial_condition 0.00086
#  Val [ 0.00543 ]<p>Epoch 32/50 Losses 0.00752
#  PDE  [ 0.00466 ]
#  boco 0.00168
#  initial_condition 0.00119
#  Val [ 0.00458 ]<p>Epoch 33/50 Losses 0.01749
#  PDE  [ 0.00510 ]
#  boco 0.00831
#  initial_condition 0.00408
#  Val [ 0.00746 ]<p>Epoch 34/50 Losses 0.00898
#  PDE  [ 0.00497 ]
#  boco 0.00249
#  initial_condition 0.00151
#  Val [ 0.00478 ]<p>Epoch 35/50 Losses 0.00728
#  PDE  [ 0.00492 ]
#  boco 0.00137
#  initial_condition 0.00099
#  Val [ 0.00455 ]<p>Epoch 36/50 Losses 0.00834
#  PDE  [ 0.00498 ]
#  boco 0.00207
#  initial_condition 0.00130
#  Val [ 0.00508 ]<p>Epoch 37/50 Losses 0.00850
#  PDE  [ 0.00464 ]
#  boco 0.00245
#  initial_condition 0.00141
#  Val [ 0.00481 ]<p>Epoch 38/50 Losses 0.00808
#  PDE  [ 0.00500 ]
#  boco 0.00185
#  initial_condition 0.00123
#  Val [ 0.00478 ]<p>Epoch 39/50 Losses 0.00946
#  PDE  [ 0.00476 ]
#  boco 0.00285
#  initial_condition 0.00185
#  Val [ 0.00453 ]<p>Epoch 40/50 Losses 0.00789
#  PDE  [ 0.00486 ]
#  boco 0.00184
#  initial_condition 0.00120
#  Val [ 0.00445 ]<p>Epoch 41/50 Losses 0.00780
#  PDE  [ 0.00485 ]
#  boco 0.00177
#  initial_condition 0.00118
#  Val [ 0.00602 ]<p>Epoch 42/50 Losses 0.01082
#  PDE  [ 0.00498 ]
#  boco 0.00351
#  initial_condition 0.00233
#  Val [ 0.00439 ]<p>Epoch 43/50 Losses 0.00664
#  PDE  [ 0.00470 ]
#  boco 0.00113
#  initial_condition 0.00081
#  Val [ 0.00514 ]<p>Epoch 44/50 Losses 0.00874
#  PDE  [ 0.00492 ]
#  boco 0.00244
#  initial_condition 0.00138
#  Val [ 0.00516 ]<p>Epoch 45/50 Losses 0.01001
#  PDE  [ 0.00507 ]
#  boco 0.00324
#  initial_condition 0.00170
#  Val [ 0.00548 ]<p>Epoch 46/50 Losses 0.00865
#  PDE  [ 0.00510 ]
#  boco 0.00228
#  initial_condition 0.00127
#  Val [ 0.00449 ]<p>Epoch 47/50 Losses 0.01021
#  PDE  [ 0.00486 ]
#  boco 0.00327
#  initial_condition 0.00207
#  Val [ 0.00534 ]<p>Epoch 48/50 Losses 0.01043
#  PDE  [ 0.00622 ]
#  boco 0.00260
#  initial_condition 0.00161
#  Val [ 0.00499 ]<p>Epoch 49/50 Losses 0.01194
#  PDE  [ 0.00561 ]
#  boco 0.00403
#  initial_condition 0.00231
#  Val [ 0.00596 ]<p>Epoch 50/50 Losses 0.00853
#  PDE  [ 0.00531 ]
#  boco 0.00203
#  initial_condition 0.00119
#  Val [ 0.00694 ]
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.plot(hist['train_loss'], label="train_loss")
ax1.plot(hist['val_loss'], label="val_loss")
ax1.grid(True)
ax1.legend()
ax1.set_yscale("log")
for boco in pde.bocos:
    ax2.plot(hist['bocos'][boco.name], label=boco.name)
ax2.legend()
ax2.grid(True)
ax2.set_yscale("log")
plt.show()

# %% [markdown]
# Finally, we can evaluate our solution. Since we trained it for also the parameter *u* we can obtain a solution for any value of *u* without having to perform additional computations.

# %%
# evaluate the solution
x = np.linspace(0,1,50)
t = np.linspace(0,1,50)
u = np.linspace(0,1,5)
p, p0, l2 = [], [], []
for _t in t:
    _p, _p0, _l2 = [], [], []
    for _u in u:
        _p0.append(np.sin(2.*math.pi*(x-_u*_t)))
        pde.evaluate({'x': x, 't': np.array([_t]), 'u': np.array([_u])}, device)
        _p.append(pde.outputs['p'])
        _l2.append(np.mean((pde.outputs['p']-np.sin(2.*math.pi*(x-_u*_t)))**2))
    p.append(_p)
    p0.append(_p0)
    l2.append(_l2)
    
from matplotlib import animation, rc
rc('animation', html='html5')

def plot(x, p, p0, t, l2, u):
    ax.clear()
    #tit = ax.set_title(f"t = {t:.2f}, l2 = {l2:.5f}", fontsize=14)
    tit = ax.set_title(f"t = {t:.2f}", fontsize=14)
    for i, _u in enumerate(u):
        ax.plot(x, p0[i], label=f"Exact (u = {_u})")
        ax.plot(x, p[i], ".k", label=f"NN (u = {_u}, l2 = {l2[i]:.5f})")
    ax.set_xlabel("x", fontsize=14)
    ax.set_ylabel("p", fontsize=14, rotation=np.pi/2)
    ax.legend(loc="upper right")
    ax.grid(True)
    ax.set_xlim([0, 1])
    ax.set_ylim([-1.2, 1.2])
    return [tit]

def get_anim(fig, ax, x, p, p0, t, l2, u):
    def anim(i):
        return plot(x, p[i], p0[i], t[i], l2[i], u)
    return anim

fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, autoscale_on=False)
animate = get_anim(fig, ax, x, p, p0, t, l2, u)
anim = animation.FuncAnimation(fig, animate, frames=len(t), interval=100, blit=True)

# %%
anim
# Out:
# <video width="720" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...
