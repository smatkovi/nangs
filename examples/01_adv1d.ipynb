# %% [markdown]
# # One-dimensional advection equation
#
# We want to solve the following PDE:
#
# \begin{equation}
#     \frac{\partial \phi}{\partial t} + u \frac{\partial \phi}{\partial x} = 0
# \end{equation}
#
# The independen variables (i.e, $x$ and $t$) are used as input values for the NN, and the solution (i.e. $\phi$) is the output. In order to find the solution, at each step the NN outputs are derived w.r.t the inputs. Then, a loss function that matches the PDE is built and the weights are updated accordingly. If the loss function goes to zero, we can assume that our NN is indeed the solution to our PDE. We will try to find a general solution for different values of $u$, so it will be set also as an input.

# %%
# autoreload nangs
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# imports
import math
import numpy as np 
import matplotlib.pyplot as plt 

import torch
cuda = True
device = "cuda" if torch.cuda.is_available() and cuda else "cpu"

# %% [markdown]
# ## Define PDE
#
# First we define our PDE and set the values for training.

# %%
# imports
from nangs.pde import PDE
from nangs.bocos import PeriodicBoco, DirichletBoco

# define our PDE
class MyPDE(PDE):
    def __init__(self, inputs=None, outputs=None):
        super().__init__(inputs, outputs)
    # the loss of our NN is the PDE !
    def computePDELoss(self, grads, inputs, outputs, params): 
        dpdt, dpdx = grads['p']['t'], grads['p']['x']
        u = inputs['u']
        return [dpdt + u*dpdx]

# instanciate pde with keys for inputs/outputs
pde = MyPDE(inputs=['x', 't', 'u'], outputs=['p'])

# define input values for training
x_t = np.linspace(0,1,30)
t_t = np.linspace(0,1,20)
u_t = np.linspace(0,1,10)
pde.setValues({'x': x_t, 't': t_t, 'u': u_t})

# periodic b.c for the space dimension
x1, x2 = np.array([0]), np.array([1])
boco = PeriodicBoco('boco', {'x': x1, 't': t_t, 'u': u_t}, {'x': x2, 't': t_t, 'u': u_t})
pde.addBoco(boco)

# initial condition (dirichlet for temporal dimension)
p00, p0 = np.sin(2.*math.pi*x_t), np.array([])
for i in u_t:
    p0 = np.concatenate((p0,p00)) # one for each value of 'u', keeping the order (x, t, u)
boco = DirichletBoco('initial_condition', {'x': x_t, 't': np.array([0]), 'u': u_t}, {'p': p0})
pde.addBoco(boco)

# define input values for validation
x_v = np.linspace(0,1,25)
t_v = np.linspace(0,1,15)
u_v = np.linspace(0,1,5)
pde.setValues({'x': x_v, 't': t_v, 'u': u_v}, train=False)

# %% [markdown]
# Now we define a topology for our solution and set the training parameters. Then we can find a solution for our PDE.

# %%
# define solution topology
topo = {'layers': 5, 'neurons': 1024, 'activations': 'relu'}
pde.buildSolution(topo)

# set optimization parameters
pde.compile()

# %%
# find the solution
hist = pde.solve(device, 'adv1d_best.pth')
# Out:
# Epoch 1/30 Losses 0.10367
#  PDE  [ 0.02428 ]
#  boco 0.02011
#  initial_condition 0.05927
#  Val [ 0.02505 ]<p>Epoch 2/30 Losses 0.01965
#  PDE  [ 0.01033 ]
#  boco 0.00616
#  initial_condition 0.00315
#  Val [ 0.01664 ]<p>Epoch 3/30 Losses 0.01455
#  PDE  [ 0.00823 ]
#  boco 0.00419
#  initial_condition 0.00213
#  Val [ 0.00699 ]<p>Epoch 4/30 Losses 0.01326
#  PDE  [ 0.00761 ]
#  boco 0.00383
#  initial_condition 0.00182
#  Val [ 0.00571 ]<p>Epoch 5/30 Losses 0.01136
#  PDE  [ 0.00736 ]
#  boco 0.00259
#  initial_condition 0.00141
#  Val [ 0.00631 ]<p>Epoch 6/30 Losses 0.01104
#  PDE  [ 0.00671 ]
#  boco 0.00291
#  initial_condition 0.00142
#  Val [ 0.00592 ]<p>Epoch 7/30 Losses 0.01023
#  PDE  [ 0.00591 ]
#  boco 0.00302
#  initial_condition 0.00130
#  Val [ 0.00683 ]<p>Epoch 8/30 Losses 0.01038
#  PDE  [ 0.00702 ]
#  boco 0.00215
#  initial_condition 0.00121
#  Val [ 0.00538 ]<p>Epoch 9/30 Losses 0.00964
#  PDE  [ 0.00583 ]
#  boco 0.00261
#  initial_condition 0.00120
#  Val [ 0.01014 ]<p>Epoch 10/30 Losses 0.00893
#  PDE  [ 0.00564 ]
#  boco 0.00223
#  initial_condition 0.00107
#  Val [ 0.00518 ]<p>Epoch 11/30 Losses 0.00951
#  PDE  [ 0.00591 ]
#  boco 0.00243
#  initial_condition 0.00117
#  Val [ 0.00613 ]<p>Epoch 12/30 Losses 0.00911
#  PDE  [ 0.00585 ]
#  boco 0.00220
#  initial_condition 0.00106
#  Val [ 0.00595 ]<p>Epoch 13/30 Losses 0.00962
#  PDE  [ 0.00608 ]
#  boco 0.00238
#  initial_condition 0.00116
#  Val [ 0.00516 ]<p>Epoch 14/30 Losses 0.00856
#  PDE  [ 0.00588 ]
#  boco 0.00173
#  initial_condition 0.00095
#  Val [ 0.00565 ]<p>Epoch 15/30 Losses 0.00838
#  PDE  [ 0.00553 ]
#  boco 0.00188
#  initial_condition 0.00097
#  Val [ 0.00666 ]<p>Epoch 16/30 Losses 0.00855
#  PDE  [ 0.00546 ]
#  boco 0.00207
#  initial_condition 0.00101
#  Val [ 0.00509 ]<p>Epoch 17/30 Losses 0.00878
#  PDE  [ 0.00566 ]
#  boco 0.00211
#  initial_condition 0.00102
#  Val [ 0.00467 ]<p>Epoch 18/30 Losses 0.00851
#  PDE  [ 0.00590 ]
#  boco 0.00166
#  initial_condition 0.00094
#  Val [ 0.00762 ]<p>Epoch 19/30 Losses 0.00839
#  PDE  [ 0.00572 ]
#  boco 0.00170
#  initial_condition 0.00097
#  Val [ 0.00435 ]<p>Epoch 20/30 Losses 0.00766
#  PDE  [ 0.00509 ]
#  boco 0.00172
#  initial_condition 0.00085
#  Val [ 0.00542 ]<p>Epoch 21/30 Losses 0.00891
#  PDE  [ 0.00638 ]
#  boco 0.00156
#  initial_condition 0.00096
#  Val [ 0.00599 ]<p>Epoch 22/30 Losses 0.00851
#  PDE  [ 0.00570 ]
#  boco 0.00185
#  initial_condition 0.00097
#  Val [ 0.00573 ]<p>Epoch 23/30 Losses 0.00820
#  PDE  [ 0.00577 ]
#  boco 0.00156
#  initial_condition 0.00088
#  Val [ 0.00581 ]<p>Epoch 24/30 Losses 0.00825
#  PDE  [ 0.00602 ]
#  boco 0.00136
#  initial_condition 0.00087
#  Val [ 0.00654 ]<p>Epoch 25/30 Losses 0.00942
#  PDE  [ 0.00626 ]
#  boco 0.00204
#  initial_condition 0.00113
#  Val [ 0.00538 ]<p>Epoch 26/30 Losses 0.00902
#  PDE  [ 0.00660 ]
#  boco 0.00144
#  initial_condition 0.00098
#  Val [ 0.00541 ]<p>Epoch 27/30 Losses 0.00947
#  PDE  [ 0.00677 ]
#  boco 0.00164
#  initial_condition 0.00106
#  Val [ 0.00522 ]<p>Epoch 28/30 Losses 0.00912
#  PDE  [ 0.00654 ]
#  boco 0.00160
#  initial_condition 0.00098
#  Val [ 0.00571 ]<p>Epoch 29/30 Losses 0.00896
#  PDE  [ 0.00636 ]
#  boco 0.00161
#  initial_condition 0.00100
#  Val [ 0.00733 ]<p>Epoch 30/30 Losses 0.00829
#  PDE  [ 0.00617 ]
#  boco 0.00128
#  initial_condition 0.00084
#  Val [ 0.00666 ]
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.plot(hist['train_loss'], label="train_loss")
ax1.plot(hist['val_loss'], label="val_loss")
ax1.grid(True)
ax1.legend()
ax1.set_yscale("log")
for boco in pde.bocos:
    ax2.plot(hist['bocos'][boco.name], label=boco.name)
ax2.legend()
ax2.grid(True)
ax2.set_yscale("log")
plt.show()

# %% [markdown]
# Finally, we can evaluate our solution.

# %%
# evaluate the solution
pde.load_state_dict('adv1d_best.pth')
x = np.linspace(0,1,50)
t = np.linspace(0,1,50)
u = np.array([0.655])
p, p0, l2 = [], [], []
for _t in t:
    _p0 = np.sin(2.*math.pi*(x-u*_t))
    pde.evaluate({'x': x, 't': np.array([_t]), 'u': u}, device)
    _p = pde.outputs['p']
    _l2 = np.mean((_p - _p0)**2)
    p.append(_p)
    p0.append(_p0)
    l2.append(_l2)
    
from matplotlib import animation, rc
rc('animation', html='html5')

def plot(x, p, p0, t, l2):
    ax.clear()
    tit = ax.set_title(f"t = {t:.2f}, l2 = {l2:.5f}", fontsize=14)
    ax.plot(x, p0, "-k", label="Exact")
    ax.plot(x, p, "g^", label="NN")
    ax.set_xlabel("x", fontsize=14)
    ax.set_ylabel("p", fontsize=14, rotation=np.pi/2)
    ax.legend(loc="upper left")
    ax.grid(True)
    ax.set_xlim([0, 1])
    ax.set_ylim([-1.2, 1.2])
    return [tit]

def get_anim(fig, ax, x, p, p0, t, l2):
    def anim(i):
        return plot(x, p[i], p0[i], t[i], l2[i])
    return anim

fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, autoscale_on=False)
animate = get_anim(fig, ax, x, p, p0, t, l2)
anim = animation.FuncAnimation(fig, animate, frames=len(t), interval=100, blit=True)

# %%
anim
# Out:
# <video width="720" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...
