# %% [markdown]
# ## Smith-Hutton Problem
#
# We want to solve the following PDE:
#
# \begin{equation}
#     u \frac{\partial \phi}{\partial x} + v \frac{\partial \phi}{\partial y} = 0
# \end{equation}
#
# The independen variables (i.e, $x$, $y$) are used as input values for the NN, and the solution (i.e. $\phi(x,y)$) is the output. In order to find the solution, at each step the NN outputs are derived w.r.t the inputs. Then, a loss function that matches the PDE is built and the weights are updated accordingly. If the loss function goes to zero, we can assume that our NN is indeed the solution to our PDE. We will try to find a general solution for different values of $u$, so it will be set also as an input. The geometry of the problem is as follows:
#
# ![sh](pics/sh.png)

# %%
# autoreload nangs
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
#imports
import math
import numpy as np 
import matplotlib.pyplot as plt 
import torch

# %% [markdown]
# First we define our PDE and set the values for training.

# %%
from nangs.pde import PDE
from nangs.bocos import PeriodicBoco, DirichletBoco, NeumannBoco
from nangs.solutions import MLP

class MyPDE(PDE):
    def __init__(self, inputs=None, outputs=None):
        super().__init__(inputs, outputs)
    def computePDELoss(self, grads, inputs, outputs, params): 
        dpdx, dpdy = grads['p']['x'], grads['p']['y']
        x, y = inputs['x'], inputs['y']
        u, v = 2*y*(1-x**2), -2*x*(1-y**2)
        return [u*dpdx + v*dpdy]

# instanciate pde
pde = MyPDE(inputs=['x', 'y'], outputs=['p'])

# define input values
x = np.linspace(-1,1,60)
y = np.linspace(0,1,30)

pde.setValues({'x': x, 'y': y})

x_v = np.linspace(-1,1,30)
y_v = np.linspace(0,1,15)
pde.setValues({'x': x_v, 'y': y_v}, train=False)

# %% [markdown]
# Boundary conditions.

# %%
# left and rigth b.c 
ALPHA = 10
x1, x2 = np.array([-1, 1]), np.array([1])
p = np.zeros(2*len(y))
for i in range(2*len(y)): p[i] = 1. - math.tanh(ALPHA)
boco = DirichletBoco('left_rigth', {'x': x1, 'y': y}, {'p': p})
pde.addBoco(boco)

# top b.c 
y2 = np.array([1])
p = np.zeros(len(x))
for i in range(len(x)): p[i] = 1. - math.tanh(ALPHA)
boco = DirichletBoco('top', {'x': x, 'y': y2}, {'p': p})
pde.addBoco(boco)

# bottom b.c
y1 = np.array([0])
x1, x2, p1 = [], [], []
for i in range(len(x)): 
    if x[i] < 0:
        x1.append(x[i])
        p1.append(1.+math.tanh(ALPHA*(2*x[i]+1)))
    else:
        x2.append(x[i])
x1, x2, p1 = np.array(x1), np.array(x2), np.array(p1) 

# bottom left b.c
boco = DirichletBoco('bottom_left', {'x': x1, 'y': y1}, {'p': p1})
pde.addBoco(boco)

# bottom right b.c
boco = NeumannBoco('bottom_right', {'x': x2, 'y': y1}, grads={'p': 'y'})
pde.addBoco(boco)

# %%
plt.plot(x1,p1)
plt.xlabel('x')
plt.ylabel('p      ', rotation=np.pi/2)
plt.title('Solution at y=0')
plt.grid()
plt.show()

# %% [markdown]
# The objective is to reproduce the inflow ($y$=0 and $x<0$) at the outlet ($y$=0 and $x>0$).

# %% [markdown]
# Now we define a topology for our solution and set the training parameters. Then we can find a solution for our PDE.

# %%
# define solution topology
mlp = MLP(pde.n_inputs, pde.n_outputs, 5, 2048)
optimizer = torch.optim.Adam(mlp.parameters(), lr=3e-4)
pde.compile(mlp, optimizer)

# %%
# find the solution
hist = pde.solve()
# Out:
# Epoch 1/30 Losses 0.30990
#  PDE  [ 0.04466 ]
#  left_rigth 0.01039
#  top 0.00669
#  bottom_left 0.23285
#  bottom_right 0.01531
#  Val [ 0.01753 ]<p>Epoch 2/30 Losses 0.02908
#  PDE  [ 0.01289 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.01435
#  bottom_right 0.00182
#  Val [ 0.01281 ]<p>Epoch 3/30 Losses 0.02360
#  PDE  [ 0.01174 ]
#  left_rigth 0.00005
#  top 0.00005
#  bottom_left 0.00978
#  bottom_right 0.00199
#  Val [ 0.01805 ]<p>Epoch 4/30 Losses 0.02615
#  PDE  [ 0.01195 ]
#  left_rigth 0.00003
#  top 0.00003
#  bottom_left 0.00835
#  bottom_right 0.00580
#  Val [ 0.01723 ]<p>Epoch 5/30 Losses 0.02226
#  PDE  [ 0.00913 ]
#  left_rigth 0.00005
#  top 0.00005
#  bottom_left 0.01035
#  bottom_right 0.00269
#  Val [ 0.00418 ]<p>Epoch 6/30 Losses 0.01823
#  PDE  [ 0.00990 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00560
#  bottom_right 0.00271
#  Val [ 0.00497 ]<p>Epoch 7/30 Losses 0.01427
#  PDE  [ 0.00787 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00499
#  bottom_right 0.00140
#  Val [ 0.00568 ]<p>Epoch 8/30 Losses 0.01062
#  PDE  [ 0.00575 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00300
#  bottom_right 0.00187
#  Val [ 0.00744 ]<p>Epoch 9/30 Losses 0.01321
#  PDE  [ 0.00670 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00458
#  bottom_right 0.00191
#  Val [ 0.00967 ]<p>Epoch 10/30 Losses 0.01061
#  PDE  [ 0.00467 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00296
#  bottom_right 0.00298
#  Val [ 0.00430 ]<p>Epoch 11/30 Losses 0.01304
#  PDE  [ 0.00811 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00356
#  bottom_right 0.00136
#  Val [ 0.01640 ]<p>Epoch 12/30 Losses 0.07422
#  PDE  [ 0.00865 ]
#  left_rigth 0.00014
#  top 0.00015
#  bottom_left 0.06247
#  bottom_right 0.00281
#  Val [ 0.00622 ]<p>Epoch 13/30 Losses 0.01126
#  PDE  [ 0.00718 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00315
#  bottom_right 0.00090
#  Val [ 0.00405 ]<p>Epoch 14/30 Losses 0.00873
#  PDE  [ 0.00559 ]
#  left_rigth 0.00005
#  top 0.00005
#  bottom_left 0.00258
#  bottom_right 0.00045
#  Val [ 0.00814 ]<p>Epoch 15/30 Losses 0.00722
#  PDE  [ 0.00442 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00190
#  bottom_right 0.00087
#  Val [ 0.00686 ]<p>Epoch 16/30 Losses 0.01224
#  PDE  [ 0.00654 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00388
#  bottom_right 0.00180
#  Val [ 0.00587 ]<p>Epoch 17/30 Losses 0.00849
#  PDE  [ 0.00523 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00225
#  bottom_right 0.00100
#  Val [ 0.00574 ]<p>Epoch 18/30 Losses 0.00718
#  PDE  [ 0.00477 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00172
#  bottom_right 0.00069
#  Val [ 0.01079 ]<p>Epoch 19/30 Losses 0.00618
#  PDE  [ 0.00376 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00157
#  bottom_right 0.00085
#  Val [ 0.00625 ]<p>Epoch 20/30 Losses 0.00639
#  PDE  [ 0.00395 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00148
#  bottom_right 0.00096
#  Val [ 0.00610 ]<p>Epoch 21/30 Losses 0.00882
#  PDE  [ 0.00482 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00223
#  bottom_right 0.00177
#  Val [ 0.00588 ]<p>Epoch 22/30 Losses 0.00987
#  PDE  [ 0.00500 ]
#  left_rigth 0.00001
#  top 0.00000
#  bottom_left 0.00367
#  bottom_right 0.00119
#  Val [ 0.00324 ]<p>Epoch 23/30 Losses 0.01038
#  PDE  [ 0.00594 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00321
#  bottom_right 0.00122
#  Val [ 0.00298 ]<p>Epoch 24/30 Losses 0.00954
#  PDE  [ 0.00515 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00279
#  bottom_right 0.00158
#  Val [ 0.00381 ]<p>Epoch 25/30 Losses 0.00604
#  PDE  [ 0.00354 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00160
#  bottom_right 0.00089
#  Val [ 0.00314 ]<p>Epoch 26/30 Losses 0.00521
#  PDE  [ 0.00305 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00133
#  bottom_right 0.00082
#  Val [ 0.00501 ]<p>Epoch 27/30 Losses 0.00660
#  PDE  [ 0.00452 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00153
#  bottom_right 0.00055
#  Val [ 0.00556 ]<p>Epoch 28/30 Losses 0.01040
#  PDE  [ 0.00567 ]
#  left_rigth 0.00001
#  top 0.00001
#  bottom_left 0.00340
#  bottom_right 0.00132
#  Val [ 0.00520 ]<p>Epoch 29/30 Losses 0.00550
#  PDE  [ 0.00305 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00161
#  bottom_right 0.00084
#  Val [ 0.00283 ]<p>Epoch 30/30 Losses 0.00419
#  PDE  [ 0.00293 ]
#  left_rigth 0.00000
#  top 0.00000
#  bottom_left 0.00091
#  bottom_right 0.00034
#  Val [ 0.00324 ]
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.plot(hist['train_loss'], label="train_loss")
ax1.plot(hist['val_loss'], label="val_loss")
ax1.grid(True)
ax1.legend()
ax1.set_yscale("log")
for boco in pde.bocos:
    ax2.plot(hist['bocos'][boco.name], label=boco.name)
ax2.legend()
ax2.grid(True)
ax2.set_yscale("log")
plt.show()

# %% [markdown]
# Finally, we can evaluate our solution.

# %%
# evaluate the solution
x = np.linspace(-1,1,100)
y = np.linspace(0,1,50)
pde.evaluate({'x': x, 'y': y})
p = pde.outputs['p']
plt.imshow(p.reshape((len(y),len(x))), vmin=p.min(), vmax=p.max(), origin='lower',
           extent=[x.min(), x.max(), y.min(), y.max()])
plt.colorbar()
plt.show()

# %%
x = np.linspace(-1,1,200)
y = np.array([0])
pde.evaluate({'x': x, 'y': y})
p = pde.outputs['p']
plt.plot(x1,p1)
plt.plot(x1+1,np.flip(p1), label="exact")
plt.plot(x, p, '.k', label="predicted")
plt.legend()
plt.xlabel('x')
plt.ylabel('p      ', rotation=np.pi/2)
plt.title('Solution at y=0')
plt.grid()
plt.show()
