# %% [markdown]
# # Shock Tube
#
# > WORK IN PROGRESS !!!
#
# In this example we are going to solve the Euler equations for a one-dimensional shock tube.
#
# \begin{equation}
#     \begin{array}{c}
#         \rho_t + (\rho u)_x = 0 \\
#         (\rho u)_t + (\rho u u + p)_x = 0 \\
#         (\rho e)_t + (u ( \rho e + p ))_x = 0 \\
#     \end{array}
# \end{equation}
#
# The inputs to the network will be the independent variables $x$ and $t$ and the outputs will be the density, $\rho$, the velocity $u$ and the pressure $p$. We can compute the internal energy with the expression $\rho e = 0.5 \rho u u + p/(\gamma-1)$ with $\gamma=1.4$ for air.

# %% [markdown]
# ![](https://i1.wp.com/curiosityfluids.com/wp-content/uploads/2016/07/shocktube.gif?fit=600%2C259&ssl=1)

# %%
# autoreload nangs
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# imports
import math
import numpy as np 
import matplotlib.pyplot as plt 
import torch

# %% [markdown]
# ## Define PDE
#
# First we define our PDE and set the values for training.

# %%
# imports
from nangs.pde import PDE
from nangs.bocos import PeriodicBoco, DirichletBoco
from nangs.solutions import MLP

# define our PDE
class MyPDE(PDE):
    def __init__(self, inputs, outputs, params):
        super().__init__(inputs, outputs, params)
    # the loss of our NN is the PDE !
    def computePDELoss(self, grads, inputs, outputs, params): 
        drdt = grads['r']['t']        
        #dudt = grads['u']['t']        
        #dpdt = grads['p']['t']        
        
        r, u, p = outputs['r'], outputs['u'], outputs['p']
        ru = r*u
        drudx = self.computeGrad(ru, 'x')
        drudt = self.computeGrad(ru, 't')
        ruup = r*u*u + p
        druupdx =  self.computeGrad(ruup, 'x')
        re = p/(params['g']-1) + 0.5*r*u*u
        dredt = self.computeGrad(re, 't')
        repu = (re+p)*u
        drepudx = self.computeGrad(repu, 'x')
        
        return [
            drdt + drudx,
            drudt + druupdx,
            dredt + drepudx 
        ]

# instanciate pde with keys for inputs/outputs
pde = MyPDE(inputs=['x', 't'], outputs=['r', 'u', 'p'], params=['g'])

# define input values for training
x = np.linspace(0,1,200)
t = np.linspace(0,0.0001,5)
g = 1.4

pde.setValues({'x': x, 't': t, 'g': np.array([g])})

# define input values for validation
x_v = np.linspace(0,1,25)
t_v = np.linspace(0,1,15)
pde.setValues({'x': x_v, 't': t_v}, train=False)

# %%
# initial condition (dirichlet for temporal dimension)
rl, pl, rr, pr = 10, 10/g, 1, 1/g
r0 = np.zeros(len(x))
u0 = np.zeros(len(x))
p0 = np.zeros(len(x))
for i, _x in enumerate(x):
    u0[i] = 0.
    if _x < 0.5:
        r0[i] = rl
        p0[i] = pl
    else:
        r0[i] = rr
        p0[i] = pr
    
boco = DirichletBoco('initial_condition', {'x': x, 't': np.array([0])}, {'r': r0, 'u': u0, 'p': p0})
pde.addBoco(boco)

# dirichlet b.c for the space dimension
x1, x2 = np.array([0]), np.array([1])
ones = np.ones(len(t))
boco = DirichletBoco('boco_left', {'x': x1, 't': t}, {'r': r0[0]*ones, 'u': u0[0]*ones, 'p': p0[0]*ones})
pde.addBoco(boco)
boco = DirichletBoco('boco_rigth', {'x': x2, 't': t}, {'r': r0[len(x)-1]*ones, 'u': u0[len(x)-1]*ones, 'p': p0[len(x)-1]*ones})
pde.addBoco(boco)

# %% [markdown]
# Now we define a topology for our solution and set the training parameters. Then we can find a solution for our PDE.

# %%
# define solution topology
mlp = MLP(pde.n_inputs, pde.n_outputs, 2, 10)
optimizer = torch.optim.Adam(mlp.parameters(), lr=0.01)
pde.compile(mlp, optimizer)

# %%
# pre-train on initial conditions

if False:
    hist = pde.warm(epochs=1000, bocos=['initial_condition'])

    for h in hist:
        plt.plot(hist[h], label=h)
    plt.legend()
    plt.grid()
    plt.yscale("log")
    plt.show()

# %%
# visualize initial condition
#pde.evaluate({'x': x, 't': np.array([0])})

plt.plot(x, r0)
plt.plot(x, u0)
plt.plot(x, p0)
#plt.plot(x, pde.outputs['r'])
#plt.plot(x, pde.outputs['u'])
#plt.plot(x, pde.outputs['p'])
plt.legend(['$\\rho$', 'u', 'p'])#, 'NN $\\rho$', 'NN u', 'NN p'])
plt.grid()
plt.xlabel('x')
plt.show()

# %%
# find the solution
hist = pde.solve(epochs=100)
# Out:
# Epoch 1/100 Losses 53.63452
#  PDE  [ 0.00257 0.02740 0.00274 ]
#  initial_condition 18.19427
#  boco_left 32.78378
#  boco_rigth 2.64557
#  Val [ 0.03225 0.50222 0.03438 ]<p>Epoch 2/100 Losses 16.43861
#  PDE  [ 0.47441 3.12682 0.74923 ]
#  initial_condition 6.87251
#  boco_left 3.62644
#  boco_rigth 4.48951
#  Val [ 1.38065 1.32525 1.29759 ]<p>Epoch 3/100 Losses 11.15425
#  PDE  [ 0.71733 1.93343 0.58800 ]
#  initial_condition 5.71099
#  boco_left 2.93665
#  boco_rigth 1.42703
#  Val [ 5.82292 4.56953 11.78668 ]<p>Epoch 4/100 Losses 6.50548
#  PDE  [ 0.20466 2.64970 0.41985 ]
#  initial_condition 4.23122
#  boco_left 0.72723
#  boco_rigth 0.45562
#  Val [ 9.35611 13.59516 47.35480 ]<p>Epoch 5/100 Losses 6.88405
#  PDE  [ 0.27373 2.51369 1.02860 ]
#  initial_condition 4.26016
#  boco_left 0.86500
#  boco_rigth 0.48689
#  Val [ 5.68078 8.18217 20.02213 ]<p>Epoch 6/100 Losses 6.83493
#  PDE  [ 0.13884 2.35715 0.33227 ]
#  initial_condition 4.31083
#  boco_left 0.86185
#  boco_rigth 0.71950
#  Val [ 7.15000 7.41817 21.02881 ]<p>Epoch 7/100 Losses 6.02004
#  PDE  [ 0.02285 2.37585 0.04281 ]
#  initial_condition 4.14492
#  boco_left 0.45145
#  boco_rigth 0.60983
#  Val [ 5.73171 5.22651 15.24427 ]<p>Epoch 8/100 Losses 6.08062
#  PDE  [ 0.00446 2.46638 0.00687 ]
#  initial_condition 4.18397
#  boco_left 0.50197
#  boco_rigth 0.56878
#  Val [ 5.76802 5.07008 14.37098 ]<p>Epoch 9/100 Losses 6.14643
#  PDE  [ 0.00406 2.42731 0.00287 ]
#  initial_condition 4.26783
#  boco_left 0.46983
#  boco_rigth 0.59735
#  Val [ 5.34034 4.91691 13.49137 ]<p>Epoch 10/100 Losses 6.07610
#  PDE  [ 0.00466 2.54087 0.00075 ]
#  initial_condition 4.15814
#  boco_left 0.51980
#  boco_rigth 0.54940
#  Val [ 5.07030 4.54669 12.09476 ]<p>Epoch 11/100 Losses 6.15752
#  PDE  [ 0.00592 2.33311 0.00093 ]
#  initial_condition 4.24463
#  boco_left 0.51990
#  boco_rigth 0.61301
#  Val [ 5.75048 4.98536 13.51010 ]<p>Epoch 12/100 Losses 6.19289
#  PDE  [ 0.01065 2.35684 0.00377 ]
#  initial_condition 4.29660
#  boco_left 0.47522
#  boco_rigth 0.63064
#  Val [ 5.54800 4.81883 12.77933 ]<p>Epoch 13/100 Losses 6.06504
#  PDE  [ 0.01581 2.29968 0.00513 ]
#  initial_condition 4.12066
#  boco_left 0.53928
#  boco_rigth 0.63157
#  Val [ 5.55954 4.89641 12.82779 ]<p>Epoch 14/100 Losses 6.17063
#  PDE  [ 0.02263 2.32342 0.00731 ]
#  initial_condition 4.17211
#  boco_left 0.57397
#  boco_rigth 0.64009
#  Val [ 4.84875 4.81885 12.00672 ]<p>Epoch 15/100 Losses 6.18751
#  PDE  [ 0.02211 2.29412 0.00245 ]
#  initial_condition 4.19430
#  boco_left 0.55902
#  boco_rigth 0.66130
#  Val [ 5.07974 4.94780 12.16697 ]<p>Epoch 16/100 Losses 6.21115
#  PDE  [ 0.03062 2.31825 0.00296 ]
#  initial_condition 4.23292
#  boco_left 0.57526
#  boco_rigth 0.61902
#  Val [ 5.01103 4.85111 11.79914 ]<p>Epoch 17/100 Losses 6.04976
#  PDE  [ 0.04332 2.20183 0.00817 ]
#  initial_condition 4.08484
#  boco_left 0.55799
#  boco_rigth 0.65582
#  Val [ 5.13516 5.43110 12.82461 ]<p>Epoch 18/100 Losses 6.23133
#  PDE  [ 0.06010 2.18291 0.01095 ]
#  initial_condition 4.25972
#  boco_left 0.52893
#  boco_rigth 0.69136
#  Val [ 3.53676 4.93130 9.97412 ]<p>Epoch 19/100 Losses 6.06864
#  PDE  [ 0.11842 2.15041 0.12983 ]
#  initial_condition 4.01117
#  boco_left 0.59099
#  boco_rigth 0.66693
#  Val [ 5.13105 5.79700 12.58168 ]<p>Epoch 20/100 Losses 6.20043
#  PDE  [ 0.08281 2.05004 0.01135 ]
#  initial_condition 4.18363
#  boco_left 0.60309
#  boco_rigth 0.69898
#  Val [ 4.07294 5.85977 12.74640 ]<p>Epoch 21/100 Losses 6.35034
#  PDE  [ 0.11050 2.18576 0.03571 ]
#  initial_condition 4.33218
#  boco_left 0.56758
#  boco_rigth 0.67326
#  Val [ 4.32536 5.88019 12.23448 ]<p>Epoch 22/100 Losses 6.15542
#  PDE  [ 0.13307 2.09399 0.01295 ]
#  initial_condition 4.19016
#  boco_left 0.54244
#  boco_rigth 0.67615
#  Val [ 5.15016 7.49862 15.77114 ]<p>Epoch 23/100 Losses 6.25649
#  PDE  [ 0.16501 1.95849 0.01787 ]
#  initial_condition 4.27810
#  boco_left 0.59016
#  boco_rigth 0.67445
#  Val [ 5.46290 8.79993 18.76383 ]<p>Epoch 24/100 Losses 5.98126
#  PDE  [ 0.20310 1.99632 0.03194 ]
#  initial_condition 4.03894
#  boco_left 0.51173
#  boco_rigth 0.68680
#  Val [ 5.96358 9.33483 20.57388 ]<p>Epoch 25/100 Losses 6.35756
#  PDE  [ 0.28075 1.89015 0.16899 ]
#  initial_condition 4.27556
#  boco_left 0.61995
#  boco_rigth 0.68209
#  Val [ 4.75370 8.49522 18.53052 ]<p>Epoch 26/100 Losses 6.31483
#  PDE  [ 0.25572 1.76816 0.07267 ]
#  initial_condition 4.29874
#  boco_left 0.67539
#  boco_rigth 0.64185
#  Val [ 4.20024 10.09540 20.62211 ]<p>Epoch 27/100 Losses 6.36410
#  PDE  [ 0.39211 1.81449 0.40462 ]
#  initial_condition 4.22843
#  boco_left 0.61907
#  boco_rigth 0.64620
#  Val [ 5.47649 10.00451 22.02931 ]<p>Epoch 28/100 Losses 6.33423
#  PDE  [ 0.29232 1.75544 0.11577 ]
#  initial_condition 4.30955
#  boco_left 0.60148
#  boco_rigth 0.70203
#  Val [ 5.93907 11.41521 25.26349 ]<p>Epoch 29/100 Losses 6.07897
#  PDE  [ 0.29710 1.75603 0.01309 ]
#  initial_condition 4.17083
#  boco_left 0.52759
#  boco_rigth 0.69181
#  Val [ 6.64568 13.94039 32.08810 ]<p>Epoch 30/100 Losses 6.17859
#  PDE  [ 0.34864 1.74676 0.04026 ]
#  initial_condition 4.30419
#  boco_left 0.55508
#  boco_rigth 0.60743
#  Val [ 6.42332 14.13756 33.14241 ]<p>Epoch 31/100 Losses 5.90677
#  PDE  [ 0.36449 1.71321 0.01571 ]
#  initial_condition 4.01959
#  boco_left 0.54570
#  boco_rigth 0.64368
#  Val [ 7.23005 17.22931 41.88113 ]<p>Epoch 32/100 Losses 5.96494
#  PDE  [ 0.40286 1.60145 0.01978 ]
#  initial_condition 4.10296
#  boco_left 0.53335
#  boco_rigth 0.65394
#  Val [ 6.79783 18.34791 45.22831 ]<p>Epoch 33/100 Losses 5.95270
#  PDE  [ 0.44093 1.59967 0.04690 ]
#  initial_condition 4.07866
#  boco_left 0.58320
#  boco_rigth 0.59501
#  Val [ 7.79770 22.38965 56.46810 ]<p>Epoch 34/100 Losses 6.02106
#  PDE  [ 0.49467 1.51923 0.12746 ]
#  initial_condition 4.12757
#  boco_left 0.54577
#  boco_rigth 0.63393
#  Val [ 11.02972 24.67675 71.21725 ]<p>Epoch 35/100 Losses 7.58898
#  PDE  [ 0.87184 1.53285 1.60542 ]
#  initial_condition 4.43041
#  boco_left 1.17323
#  boco_rigth 0.64863
#  Val [ 5.14056 9.83750 21.32560 ]<p>Epoch 36/100 Losses 6.21504
#  PDE  [ 0.35303 1.59349 0.09210 ]
#  initial_condition 4.21256
#  boco_left 0.69517
#  boco_rigth 0.62777
#  Val [ 6.64272 14.49522 34.51065 ]<p>Epoch 37/100 Losses 6.00013
#  PDE  [ 0.39532 1.66262 0.01509 ]
#  initial_condition 4.11030
#  boco_left 0.57613
#  boco_rigth 0.62270
#  Val [ 7.34215 16.84790 41.48235 ]<p>Epoch 38/100 Losses 6.00732
#  PDE  [ 0.40756 1.63392 0.01297 ]
#  initial_condition 4.10579
#  boco_left 0.53609
#  boco_rigth 0.68062
#  Val [ 7.22858 18.44278 44.93935 ]<p>Epoch 39/100 Losses 6.12861
#  PDE  [ 0.43295 1.56687 0.00819 ]
#  initial_condition 4.28641
#  boco_left 0.56663
#  boco_rigth 0.60622
#  Val [ 6.82809 18.32911 45.82526 ]<p>Epoch 40/100 Losses 6.02240
#  PDE  [ 0.46779 1.54702 0.01056 ]
#  initial_condition 4.17106
#  boco_left 0.59445
#  boco_rigth 0.58178
#  Val [ 7.83878 21.90318 56.05261 ]<p>Epoch 41/100 Losses 6.00391
#  PDE  [ 0.50098 1.56317 0.01619 ]
#  initial_condition 4.18062
#  boco_left 0.55952
#  boco_rigth 0.57033
#  Val [ 8.30638 25.21283 66.09400 ]<p>Epoch 42/100 Losses 6.04637
#  PDE  [ 0.53632 1.50754 0.01545 ]
#  initial_condition 4.18508
#  boco_left 0.54654
#  boco_rigth 0.62831
#  Val [ 7.94956 26.16043 68.69137 ]<p>Epoch 43/100 Losses 5.92215
#  PDE  [ 0.55914 1.40952 0.01657 ]
#  initial_condition 4.05202
#  boco_left 0.59808
#  boco_rigth 0.61031
#  Val [ 8.06219 30.23606 81.44664 ]<p>Epoch 44/100 Losses 6.09790
#  PDE  [ 0.57649 1.35011 0.02166 ]
#  initial_condition 4.23187
#  boco_left 0.58374
#  boco_rigth 0.63288
#  Val [ 8.72257 31.09323 85.62670 ]<p>Epoch 45/100 Losses 5.83953
#  PDE  [ 0.59791 1.39827 0.01857 ]
#  initial_condition 4.01999
#  boco_left 0.56271
#  boco_rigth 0.58525
#  Val [ 8.48061 32.18855 88.88627 ]<p>Epoch 46/100 Losses 6.13400
#  PDE  [ 0.61725 1.31909 0.00927 ]
#  initial_condition 4.29123
#  boco_left 0.58618
#  boco_rigth 0.60805
#  Val [ 8.41599 33.69238 95.39796 ]<p>Epoch 47/100 Losses 6.08517
#  PDE  [ 0.63065 1.30142 0.02015 ]
#  initial_condition 4.25608
#  boco_left 0.57824
#  boco_rigth 0.60012
#  Val [ 10.13186 38.75293 112.12905 ]<p>Epoch 48/100 Losses 5.92121
#  PDE  [ 0.65578 1.31769 0.02338 ]
#  initial_condition 4.11500
#  boco_left 0.55686
#  boco_rigth 0.58374
#  Val [ 9.70263 38.62408 112.86261 ]<p>Epoch 49/100
# /home/sebastianm/.local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/sebastianm/.local/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.plot(hist['train_loss'], label="train_loss")
ax1.plot(hist['val_loss'], label="val_loss")
ax1.grid(True)
ax1.legend()
ax1.set_yscale("log")
for boco in pde.bocos:
    ax2.plot(hist['bocos'][boco.name], label=boco.name)
ax2.legend()
ax2.grid(True)
ax2.set_yscale("log")
plt.show()

# %% [markdown]
# Finally, we can evaluate our solution.

# %%
# evaluate the solution
x = np.linspace(0,1,100)
t = np.linspace(0,0.0001,20)
r, u, p = [], [], []
for _t in t:
    pde.evaluate({'x': x, 't': np.array([_t])})
    r.append(pde.outputs['r'])
    u.append(pde.outputs['u'])
    p.append(pde.outputs['p'])

from matplotlib import animation, rc
rc('animation', html='html5')

def plot(x, r, u, p, t):
    ax.clear()
    tit = ax.set_title(f"t = {t:.4f}", fontsize=14)
    ax.plot(x, r, label="$\\rho$")
    ax.plot(x, u, label="u")
    ax.plot(x, p, label="p")
    ax.set_xlabel("x", fontsize=14)
    ax.legend(loc="upper right")
    ax.grid(True)
    ax.set_xlim([0, 1])
    ax.set_ylim([-0.2, 10.2])
    return [tit]

def get_anim(fig, ax, x, r, u, p, t):
    def anim(i):
        return plot(x, r[i], u[i], p[i], t[i])
    return anim

fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, autoscale_on=False)
animate = get_anim(fig, ax, x, r, u, p, t)
anim = animation.FuncAnimation(fig, animate, frames=len(t), interval=100, blit=True)

# %%
anim
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     160         try:
# --> 161             return self.avail[name]
#     162         except KeyError:
#
# KeyError: 'ffmpeg'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in _repr_html_(self)
#    1387         fmt = rcParams['animation.html']
#    1388         if fmt == 'html5':
# -> 1389             return self.to_html5_video()
#    1390         elif fmt == 'jshtml':
#    1391             return self.to_jshtml()
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in to_html5_video(self, embed_limit)
#    1324                 # We create a writer manually so that we can get the
#    1325                 # appropriate size for the tag
# -> 1326                 Writer = writers[rcParams['animation.writer']]
#    1327                 writer = Writer(codec='h264',
#    1328                                 bitrate=rcParams['animation.bitrate'],
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/animation.py in __getitem__(self, name)
#     162         except KeyError:
#     163             raise RuntimeError(
# --> 164                 'Requested MovieWriter ({}) not available'.format(name))
#     165
#     166
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available
