# %% [markdown]
# # Shock Tube
#
# > WORK IN PROGRESS !!!
#
# In this example we are going to solve the Euler equations for a one-dimensional shock tube.
#
# \begin{equation}
#     \begin{array}{c}
#         \rho_t + (\rho u)_x = 0 \\
#         (\rho u)_t + (\rho u u + p)_x = 0 \\
#         (\rho e)_t + (u ( \rho e + p ))_x = 0 \\
#     \end{array}
# \end{equation}
#
# The inputs to the network will be the independent variables $x$ and $t$ and the outputs will be the density, $\rho$, the velocity $u$ and the pressure $p$. We can compute the internal energy with the expression $\rho e = 0.5 \rho u u + p/(\gamma-1)$ with $\gamma=1.4$ for air.

# %% [markdown]
# ![](https://i1.wp.com/curiosityfluids.com/wp-content/uploads/2016/07/shocktube.gif?fit=600%2C259&ssl=1)

# %%
# autoreload nangs
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# imports
import math
import numpy as np 
import matplotlib.pyplot as plt 
import torch

# %% [markdown]
# ## Define PDE
#
# First we define our PDE and set the values for training.

# %%
# imports
from nangs.pde import PDE
from nangs.bocos import PeriodicBoco, DirichletBoco
from nangs.solutions import MLP

# define our PDE
class MyPDE(PDE):
    def __init__(self, inputs, outputs, params):
        super().__init__(inputs, outputs, params)
    # the loss of our NN is the PDE !
    def computePDELoss(self, grads, inputs, outputs, params): 
        drdt = grads['r']['t']        
        #dudt = grads['u']['t']        
        #dpdt = grads['p']['t']        
        
        r, u, p = outputs['r'], outputs['u'], outputs['p']
        ru = r*u
        drudx = self.computeGrad(ru, 'x')
        drudt = self.computeGrad(ru, 't')
        ruup = r*u*u + p
        druupdx =  self.computeGrad(ruup, 'x')
        re = p/(params['g']-1) + 0.5*r*u*u
        dredt = self.computeGrad(re, 't')
        repu = (re+p)*u
        drepudx = self.computeGrad(repu, 'x')
        
        return [
            drdt + drudx,
            drudt + druupdx,
            dredt + drepudx 
        ]

# instanciate pde with keys for inputs/outputs
pde = MyPDE(inputs=['x', 't'], outputs=['r', 'u', 'p'], params=['g'])

# define input values for training
x = np.linspace(0,1,200)
t = np.linspace(0,0.0001,5)
g = 1.4

pde.setValues({'x': x, 't': t, 'g': np.array([g])})

# define input values for validation
x_v = np.linspace(0,1,25)
t_v = np.linspace(0,1,15)
pde.setValues({'x': x_v, 't': t_v}, train=False)

# %%
# initial condition (dirichlet for temporal dimension)
rl, pl, rr, pr = 10, 10/g, 1, 1/g
r0 = np.zeros(len(x))
u0 = np.zeros(len(x))
p0 = np.zeros(len(x))
for i, _x in enumerate(x):
    u0[i] = 0.
    if _x < 0.5:
        r0[i] = rl
        p0[i] = pl
    else:
        r0[i] = rr
        p0[i] = pr
    
boco = DirichletBoco('initial_condition', {'x': x, 't': np.array([0])}, {'r': r0, 'u': u0, 'p': p0})
pde.addBoco(boco)

# dirichlet b.c for the space dimension
x1, x2 = np.array([0]), np.array([1])
ones = np.ones(len(t))
boco = DirichletBoco('boco_left', {'x': x1, 't': t}, {'r': r0[0]*ones, 'u': u0[0]*ones, 'p': p0[0]*ones})
pde.addBoco(boco)
boco = DirichletBoco('boco_rigth', {'x': x2, 't': t}, {'r': r0[len(x)-1]*ones, 'u': u0[len(x)-1]*ones, 'p': p0[len(x)-1]*ones})
pde.addBoco(boco)

# %% [markdown]
# Now we define a topology for our solution and set the training parameters. Then we can find a solution for our PDE.

# %%
# define solution topology
mlp = MLP(pde.n_inputs, pde.n_outputs, 2, 10)
optimizer = torch.optim.Adam(mlp.parameters(), lr=0.01)
pde.compile(mlp, optimizer)

# %%
# pre-train on initial conditions

if False:
    hist = pde.warm(epochs=1000, bocos=['initial_condition'])

    for h in hist:
        plt.plot(hist[h], label=h)
    plt.legend()
    plt.grid()
    plt.yscale("log")
    plt.show()

# %%
# visualize initial condition
#pde.evaluate({'x': x, 't': np.array([0])})

plt.plot(x, r0)
plt.plot(x, u0)
plt.plot(x, p0)
#plt.plot(x, pde.outputs['r'])
#plt.plot(x, pde.outputs['u'])
#plt.plot(x, pde.outputs['p'])
plt.legend(['$\\rho$', 'u', 'p'])#, 'NN $\\rho$', 'NN u', 'NN p'])
plt.grid()
plt.xlabel('x')
plt.show()

# %%
# find the solution
hist = pde.solve(epochs=100)
# Out:
# Epoch 1/100 Losses 58.62757
#  PDE  [ 0.00017 0.00079 0.00101 ]
#  initial_condition 19.77371
#  boco_left 38.32866
#  boco_rigth 0.52454
#  Val [ 0.00003 0.00250 0.00071 ]<p>Epoch 2/100 Losses 32.60192
#  PDE  [ 0.00021 0.00044 0.00089 ]
#  initial_condition 10.89428
#  boco_left 14.50709
#  boco_rigth 7.20003
#  Val [ 0.00039 0.00097 0.00239 ]<p>Epoch 3/100 Losses 27.55633
#  PDE  [ 0.13475 0.51051 0.47091 ]
#  initial_condition 9.55239
#  boco_left 9.41387
#  boco_rigth 8.21802
#  Val [ 0.14426 0.22699 0.13335 ]<p>Epoch 4/100 Losses 20.91638
#  PDE  [ 0.59189 0.54670 0.54522 ]
#  initial_condition 8.09087
#  boco_left 7.49855
#  boco_rigth 4.76568
#  Val [ 0.09757 0.36972 0.60730 ]<p>Epoch 5/100 Losses 14.36793
#  PDE  [ 0.92401 0.99316 0.65038 ]
#  initial_condition 6.57188
#  boco_left 3.89096
#  boco_rigth 3.04924
#  Val [ 0.22579 0.67393 0.53616 ]<p>Epoch 6/100 Losses 11.75697
#  PDE  [ 0.72944 0.98192 0.60731 ]
#  initial_condition 5.93528
#  boco_left 2.54540
#  boco_rigth 2.50340
#  Val [ 0.38250 0.75508 0.25557 ]<p>Epoch 7/100 Losses 9.30013
#  PDE  [ 0.68976 0.75474 0.65239 ]
#  initial_condition 5.02657
#  boco_left 1.63487
#  boco_rigth 1.93973
#  Val [ 0.74502 1.34052 0.96918 ]<p>Epoch 8/100 Losses 6.01877
#  PDE  [ 0.45170 0.43486 0.73594 ]
#  initial_condition 3.89424
#  boco_left 0.80656
#  boco_rigth 0.77713
#  Val [ 22.28698 30.03385 114.76870 ]<p>Epoch 9/100 Losses 4.37701
#  PDE  [ 0.26852 0.23836 0.30916 ]
#  initial_condition 3.29593
#  boco_left 0.20670
#  boco_rigth 0.60237
#  Val [ 34.05077 49.55556 192.48432 ]<p>Epoch 10/100 Losses 3.91082
#  PDE  [ 0.20454 0.20009 0.32800 ]
#  initial_condition 3.00780
#  boco_left 0.07443
#  boco_rigth 0.58438
#  Val [ 32.40826 47.39661 187.33188 ]<p>Epoch 11/100 Losses 3.82157
#  PDE  [ 0.18726 0.19352 0.46258 ]
#  initial_condition 2.92799
#  boco_left 0.04999
#  boco_rigth 0.56246
#  Val [ 29.86036 42.46873 165.35007 ]<p>Epoch 12/100 Losses 3.75934
#  PDE  [ 0.13846 0.11630 0.25642 ]
#  initial_condition 3.01609
#  boco_left 0.03332
#  boco_rigth 0.53953
#  Val [ 25.82365 37.26537 142.31368 ]<p>Epoch 13/100 Losses 3.64202
#  PDE  [ 0.15047 0.10485 0.29946 ]
#  initial_condition 2.91642
#  boco_left 0.02267
#  boco_rigth 0.51801
#  Val [ 23.52652 32.02566 123.88632 ]<p>Epoch 14/100 Losses 3.37966
#  PDE  [ 0.14107 0.09128 0.27520 ]
#  initial_condition 2.69817
#  boco_left 0.01983
#  boco_rigth 0.49247
#  Val [ 19.34466 25.46177 96.46943 ]<p>Epoch 15/100 Losses 3.23022
#  PDE  [ 0.14743 0.08331 0.22845 ]
#  initial_condition 2.58439
#  boco_left 0.02220
#  boco_rigth 0.47057
#  Val [ 14.54816 18.22783 68.68941 ]<p>Epoch 16/100 Losses 3.42247
#  PDE  [ 0.11593 0.07187 0.22591 ]
#  initial_condition 2.81162
#  boco_left 0.02418
#  boco_rigth 0.44877
#  Val [ 14.95706 18.84461 67.21325 ]<p>Epoch 17/100 Losses 3.06015
#  PDE  [ 0.13886 0.06894 0.24783 ]
#  initial_condition 2.45247
#  boco_left 0.02816
#  boco_rigth 0.42764
#  Val [ 11.69905 15.63880 52.07896 ]<p>Epoch 18/100 Losses 3.29844
#  PDE  [ 0.15195 0.07502 0.41757 ]
#  initial_condition 2.65560
#  boco_left 0.03120
#  boco_rigth 0.39679
#  Val [ 10.91354 15.55521 46.45233 ]<p>Epoch 19/100 Losses 3.08161
#  PDE  [ 0.12215 0.06345 0.22570 ]
#  initial_condition 2.51761
#  boco_left 0.03875
#  boco_rigth 0.38815
#  Val [ 9.57644 12.57414 37.81595 ]<p>Epoch 20/100 Losses 3.02186
#  PDE  [ 0.11453 0.04777 0.15852 ]
#  initial_condition 2.51020
#  boco_left 0.03858
#  boco_rigth 0.36615
#  Val [ 8.34461 12.14880 34.50414 ]<p>Epoch 21/100 Losses 3.02113
#  PDE  [ 0.13567 0.05849 0.33483 ]
#  initial_condition 2.44996
#  boco_left 0.04049
#  boco_rigth 0.35435
#  Val [ 7.40687 10.79924 29.55019 ]<p>Epoch 22/100 Losses 2.74295
#  PDE  [ 0.11321 0.04754 0.25050 ]
#  initial_condition 2.23348
#  boco_left 0.04417
#  boco_rigth 0.32822
#  Val [ 8.26181 11.28827 33.16557 ]<p>Epoch 23/100 Losses 2.86317
#  PDE  [ 0.09148 0.04358 0.12016 ]
#  initial_condition 2.40882
#  boco_left 0.04811
#  boco_rigth 0.32117
#  Val [ 6.01056 9.20142 23.94022 ]<p>Epoch 24/100 Losses 2.75518
#  PDE  [ 0.13056 0.06061 0.32401 ]
#  initial_condition 2.23423
#  boco_left 0.05132
#  boco_rigth 0.29790
#  Val [ 4.66855 7.02458 17.49083 ]<p>Epoch 25/100 Losses 2.61555
#  PDE  [ 0.09440 0.05231 0.22785 ]
#  initial_condition 2.15776
#  boco_left 0.05507
#  boco_rigth 0.27786
#  Val [ 4.43495 8.12311 18.71557 ]<p>Epoch 26/100 Losses 2.53623
#  PDE  [ 0.07493 0.04455 0.09584 ]
#  initial_condition 2.13325
#  boco_left 0.05632
#  boco_rigth 0.27488
#  Val [ 4.36137 7.96141 19.77276 ]<p>Epoch 27/100 Losses 2.65963
#  PDE  [ 0.07830 0.04215 0.13409 ]
#  initial_condition 2.26116
#  boco_left 0.05903
#  boco_rigth 0.25459
#  Val [ 4.27229 8.12998 20.97398 ]<p>Epoch 28/100 Losses 2.60685
#  PDE  [ 0.08611 0.05735 0.17700 ]
#  initial_condition 2.19601
#  boco_left 0.06097
#  boco_rigth 0.24304
#  Val [ 3.21378 6.92911 16.15971 ]<p>Epoch 29/100 Losses 2.38429
#  PDE  [ 0.09102 0.05777 0.26542 ]
#  initial_condition 1.96584
#  boco_left 0.06837
#  boco_rigth 0.21201
#  Val [ 2.60168 6.60586 16.09286 ]<p>Epoch 30/100 Losses 2.39654
#  PDE  [ 0.05775 0.06403 0.12745 ]
#  initial_condition 2.04931
#  boco_left 0.07496
#  boco_rigth 0.18919
#  Val [ 2.68853 6.38241 17.32091 ]<p>Epoch 31/100 Losses 2.35588
#  PDE  [ 0.05153 0.06018 0.13170 ]
#  initial_condition 2.01360
#  boco_left 0.08096
#  boco_rigth 0.18018
#  Val [ 3.16707 7.10621 20.60434 ]<p>Epoch 32/100 Losses 2.41175
#  PDE  [ 0.04607 0.07691 0.12715 ]
#  initial_condition 2.07236
#  boco_left 0.08268
#  boco_rigth 0.17334
#  Val [ 2.36041 5.80866 17.56447 ]<p>Epoch 33/100 Losses 2.20654
#  PDE  [ 0.07084 0.06738 0.24276 ]
#  initial_condition 1.84971
#  boco_left 0.08254
#  boco_rigth 0.14729
#  Val [ 2.32675 5.63999 17.02067 ]<p>Epoch 34/100 Losses 2.15504
#  PDE  [ 0.04553 0.07891 0.15796 ]
#  initial_condition 1.83481
#  boco_left 0.08390
#  boco_rigth 0.14219
#  Val [ 2.23051 5.71461 17.79899 ]<p>Epoch 35/100 Losses 2.17531
#  PDE  [ 0.07314 0.08310 0.22017 ]
#  initial_condition 1.83815
#  boco_left 0.08412
#  boco_rigth 0.12757
#  Val [ 2.24335 5.87087 18.11379 ]<p>Epoch 36/100 Losses 2.11642
#  PDE  [ 0.04868 0.06227 0.12762 ]
#  initial_condition 1.82682
#  boco_left 0.08480
#  boco_rigth 0.12528
#  Val [ 2.39899 6.00796 20.07412 ]<p>Epoch 37/100 Losses 2.10352
#  PDE  [ 0.04851 0.07293 0.13453 ]
#  initial_condition 1.81071
#  boco_left 0.08342
#  boco_rigth 0.12407
#  Val [ 2.62157 7.13560 23.56316 ]<p>Epoch 38/100 Losses 2.12140
#  PDE  [ 0.09289 0.07741 0.33674 ]
#  initial_condition 1.74180
#  boco_left 0.08327
#  boco_rigth 0.12732
#  Val [ 2.75848 5.48728 21.40059 ]<p>Epoch 39/100 Losses 2.27177
#  PDE  [ 0.13440 0.12169 0.48833 ]
#  initial_condition 1.83292
#  boco_left 0.08493
#  boco_rigth 0.10578
#  Val [ 2.81949 5.62105 20.15824 ]<p>Epoch 40/100 Losses 2.02635
#  PDE  [ 0.07877 0.05562 0.24089 ]
#  initial_condition 1.70238
#  boco_left 0.08231
#  boco_rigth 0.11657
#  Val [ 2.75796 7.13013 23.72144 ]<p>Epoch 41/100 Losses 1.98110
#  PDE  [ 0.03834 0.05672 0.08735 ]
#  initial_condition 1.72431
#  boco_left 0.08527
#  boco_rigth 0.11071
#  Val [ 2.81312 7.30902 24.96267 ]<p>Epoch 42/100 Losses 2.02166
#  PDE  [ 0.04583 0.07228 0.14125 ]
#  initial_condition 1.74048
#  boco_left 0.07823
#  boco_rigth 0.11649
#  Val [ 2.97387 7.61456 26.84585 ]<p>Epoch 43/100 Losses 2.07075
#  PDE  [ 0.05042 0.06866 0.14156 ]
#  initial_condition 1.79200
#  boco_left 0.07693
#  boco_rigth 0.11495
#  Val [ 2.84285 6.54112 24.48310 ]<p>Epoch 44/100 Losses 2.02772
#  PDE  [ 0.07555 0.08088 0.21039 ]
#  initial_condition 1.72488
#  boco_left 0.07844
#  boco_rigth 0.10214
#  Val [ 3.12047 8.25672 29.91480 ]<p>Epoch 45/100 Losses 2.49880
#  PDE  [ 0.23987 0.12557 0.81046 ]
#  initial_condition 1.92633
#  boco_left 0.08051
#  boco_rigth 0.09999
#  Val [ 3.25057 7.92977 27.29096 ]<p>Epoch 46/100 Losses 2.14696
#  PDE  [ 0.11282 0.07877 0.36014 ]
#  initial_condition 1.78885
#  boco_left 0.08299
#  boco_rigth 0.09122
#  Val [ 3.37766 8.04798 28.45337 ]<p>Epoch 47/100 Losses 2.03686
#  PDE  [ 0.07926 0.06336 0.21892 ]
#  initial_condition 1.74102
#  boco_left 0.07908
#  boco_rigth 0.09625
#  Val [ 3.34624 6.99033 26.74650 ]<p>Epoch 48/100 Losses 2.04773
#  PDE  [ 0.08623 0.08313 0.27177 ]
#  initial_condition 1.72508
#  boco_left 0.07677
#  boco_rigth 0.09884
#  Val [ 3.60577 8.59732 32.22918 ]<p>Epoch
# /home/sebastianm/.local/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/sebastianm/.local/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15,5))
ax1.plot(hist['train_loss'], label="train_loss")
ax1.plot(hist['val_loss'], label="val_loss")
ax1.grid(True)
ax1.legend()
ax1.set_yscale("log")
for boco in pde.bocos:
    ax2.plot(hist['bocos'][boco.name], label=boco.name)
ax2.legend()
ax2.grid(True)
ax2.set_yscale("log")
plt.show()

# %% [markdown]
# Finally, we can evaluate our solution.

# %%
# evaluate the solution
x = np.linspace(0,1,100)
t = np.linspace(0,0.0001,20)
r, u, p = [], [], []
for _t in t:
    pde.evaluate({'x': x, 't': np.array([_t])})
    r.append(pde.outputs['r'])
    u.append(pde.outputs['u'])
    p.append(pde.outputs['p'])

from matplotlib import animation, rc
rc('animation', html='html5')

def plot(x, r, u, p, t):
    ax.clear()
    tit = ax.set_title(f"t = {t:.4f}", fontsize=14)
    ax.plot(x, r, label="$\\rho$")
    ax.plot(x, u, label="u")
    ax.plot(x, p, label="p")
    ax.set_xlabel("x", fontsize=14)
    ax.legend(loc="upper right")
    ax.grid(True)
    ax.set_xlim([0, 1])
    ax.set_ylim([-0.2, 10.2])
    return [tit]

def get_anim(fig, ax, x, r, u, p, t):
    def anim(i):
        return plot(x, r[i], u[i], p[i], t[i])
    return anim

fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(111, autoscale_on=False)
animate = get_anim(fig, ax, x, r, u, p, t)
anim = animation.FuncAnimation(fig, animate, frames=len(t), interval=100, blit=True)

# %%
anim
# Out:
# <video width="720" height="360" controls autoplay loop>
#   <source type="video/mp4" src="...">
#   Your browser does not support the video tag.
# </video>
